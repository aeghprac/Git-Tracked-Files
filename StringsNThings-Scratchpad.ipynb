# %% [markdown]
# import math  #To be able to call the pi function
# import os
# import platform

# %% [markdown]
# ## Practice string slicing ##

# %%
name = "my name is alex epperly"

# %%
name[0]
# Out:
# 'm'

# %%
name[8:] #I always forget if it's before or after. But basically the colon means "etc."
# Out:
# 'is alex epperly'

# %%
name[7:]
# Out:
# ' is alex epperly'

# %%
len(name[7:])  #Just testing if this works
# Out:
# 16

# %%
help(print) #it's help() then the object
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ## Format Strings ##

# %%
f'Pi is equivalent to {math.pi}'
#By putting in curly braces you can put whatever the hell you want in there
# Out:
# 'Pi is equivalent to 3.141592653589793'

# %% [markdown]
# ### Here's the old shitty way ###

# %%
'Pi is equivalent to {}'.format(math.pi)  #Yeah, way too vebose. The new way (3.6 and later) is less verbose and more precise
# Out:
# 'Pi is equivalent to 3.141592653589793'

# %% [markdown]
# Multiline comments

# %%
myString = '''
Here is a long block of text
It keeps going until it sees \'\'\'
'''

# %%
myString
# Out:
# "\nHere is a long block of text\nIt keeps going until it sees '''\n"

# %%
#But wait, what if I don't want to see those stupid \n's?
print(myString)
# Out:
# Here is a long block of text
# It keeps going until it sees '''

# %%
print(os.name)
# Out:
# nt

# %%
help(os.name)
# Out:
# Help on built-in module nt:
#
# NAME
#     nt
#
# DESCRIPTION
#     This module provides access to operating system functionality that is
#     standardized by the C Standard and the POSIX standard (a thinly
#     disguised Unix interface).  Refer to the library manual and
#     corresponding Unix manual entries for more information on calls.
#
# CLASSES
#     builtins.object
#         DirEntry
#     builtins.tuple(builtins.object)
#         times_result
#         uname_result
#
#     class DirEntry(builtins.object)
#      |  Methods defined here:
#      |
#      |  __fspath__(self, /)
#      |      Returns the path for the entry.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  inode(self, /)
#      |      Return inode of the entry; cached per entry.
#      |
#      |  is_dir(self, /, *, follow_symlinks=True)
#      |      Return True if the entry is a directory; cached per entry.
#      |
#      |  is_file(self, /, *, follow_symlinks=True)
# ...

# %%
platform.machine()
# Out:
# 'AMD64'

# %%
platform.uname()
# Out:
# uname_result(system='Windows', node='AlexPC', release='10', version='10.0.22621', machine='AMD64')

# %%
os.getenv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14844\3075566182.py in <module>
# ----> 1 os.getenv()
#
# TypeError: getenv() missing 1 required positional argument: 'key'

# %%
os.getenv
# Out:
# <function os.getenv(key, default=None)>

# %%
os.cpu_count()
# Out:
# 16
