# %%
# You can open other files in python
f = open('Party.ipynb', 'r')
print(f)
# Out:
# <_io.TextIOWrapper name='Party.ipynb' mode='r' encoding='UTF-8'>

# %%
#

# %%
#Print out all lines
f.readlines()
# Out:
# ['{\n',
#  ' "cells": [\n',
#  '  {\n',
#  '   "cell_type": "code",\n',
#  '   "execution_count": 1,\n',
#  '   "id": "f71931d4",\n',
#  '   "metadata": {},\n',
#  '   "outputs": [\n',
#  '    {\n',
#  '     "name": "stdout",\n',
#  '     "output_type": "stream",\n',
#  '     "text": [\n',
#  '      "Y\'all\\n",\n',
#  '      "gon\\n",\n',
#  '      "make\\n",\n',
#  '      "me\\n",\n',
#  '      "lose\\n",\n',
#  '      "my\\n",\n',
#  '      "mind\\n"\n',
#  '     ]\n',
#  '    }\n',
#  '   ],\n',
#  '   "source": [\n',
#  '    "ruff_ryders= [\\"Y\'all\\", \\"gon\\", \\"make\\", \\"me\\", \\"lose\\", \\"my\\", \\"mind\\"]\\n",\n',
#  '    "for dmx in ruff_ryders:\\n",\n',
#  '    "    print(dmx)"\n',
#  '   ]\n',
#  '  },\n',
#  '  {\n',
#  '   "cell_type": "code",\n',
#  '   "execution_count": 2,\n',
#  '   "id": "74c5606c",\n',
#  '   "metadata": {},\n',
#  '   "outputs": [\n',
#  '    {\n',
#  '     "name": "stdout",\n',
#  '     "output_type": "stream",\n',
# ...

# %%
# Print out one line at a time
f.readline()
# Out:
# ''

# %%
for line in f.readlines():
        print(line)
# Out:
# {
#
#  "cells": [
#
#   {
#
#    "cell_type": "code",
#
#    "execution_count": 1,
#
#    "id": "f71931d4",
#
#    "metadata": {},
#
#    "outputs": [
#
#     {
#
#      "name": "stdout",
#
#      "output_type": "stream",
#
#      "text": [
#
#       "Y'all\n",
#
#       "gon\n",
#
#       "make\n",
#
#       "me\n",
#
#       "lose\n",
#
#       "my\n",
#
#       "mind\n"
#
#      ]
#
#     }
#
#    ],
#
#    "source": [
#
#     "ruff_ryders= [\"Y'all\", \"gon\", \"make\", \"me\", \"lose\", \"my\", \"mind\"]\n",
#
#     "for dmx in ruff_ryders:\n",
#
#     "    print(dmx)"
#
#    ]
#
#   },
#
#   {
#
#    "cell_type": "code",
#
#    "execution_count": 2,
#
#    "id": "74c5606c",
#
#    "metadata": {},
#
#    "outputs": [
#
#     {
#
#      "name": "stdout",
#
#      "output_type": "stream",
#
#      "text": [
#
#       "up\n",
#
#       "in\n",
#
#       "here\n",
#
#       "up\n",
#
#       "in\n",
#
#       "here\n"
#
#      ]
#
#     }
#
#    ],
#
#    "source": [
#
# ...

# %%
print("hello")
# Out:
# hello
