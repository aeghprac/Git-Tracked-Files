# %% [markdown]
# # A simple program to find anagrams

# %%
import pandas as pd
import numpy as np
import collections

# %%
# Make an empty list and add all text from words text file to list
#
# Interestingly, the words_alpha.txt file is every single word in the English language
# that only includes alphabetic text (No symbols or numbers, etc.)

words = []
for line in open('words_alpha.txt', 'r'):
    words.append(line.strip().lower()) # remove whitespace and uppers

# %%
# Convert to set to remove dupes
words = set(words)

# %%
# Convert back to list and sort
words = sorted(words)

# %%
# Now it's a sorted list with no duplicates. Let's check.
words
# Out:
# ['a',
#  'aa',
#  'aaa',
#  'aah',
#  'aahed',
#  'aahing',
#  'aahs',
#  'aal',
#  'aalii',
#  'aaliis',
#  'aals',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardvarks',
#  'aardwolf',
#  'aardwolves',
#  'aargh',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aarrgh',
#  'aarrghh',
#  'aaru',
#  'aas',
#  'aasvogel',
#  'aasvogels',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacas',
#  'abacate',
#  'abacaxi',
#  'abacay',
#  'abaci',
#  'abacinate',
#  'abacination',
#  'abacisci',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abacli',
#  'abacot',
#  'abacterial',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculi',
#  'abaculus',
#  'abacus',
#  'abacuses',
#  'abada',
#  'abaddon',
#  'abadejo',
#  'abadengo',
#  'abadia',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaised',
#  'abaiser',
#  'abaisse',
#  'abaissed',
#  'abaka',
#  'abakas',
#  'abalation',
#  'abalienate',
#  'abalienated',
#  'abalienating',
#  'abalienation',
#  'abalone',
#  'abalones',
#  'abama',
#  'abamp',
#  'abampere',
#  'abamperes',
#  'abamps',
#  'aband',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandoners',
#  'abandoning',
#  'abandonment',
#  'abandonments',
#  'abandons',
#  'abandum',
#  'abanet',
#  'abanga',
#  'abanic',
#  'abannition',
#  'abantes',
#  'abapical',
#  'abaptiston',
#  'abaptistum',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abasements',
#  'abaser',
#  'abasers',
#  'abases',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashes',
#  'abashing',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abashments',
#  'abasia',
#  'abasias',
#  'abasic',
#  'abasing',
#  'abasio',
#  'abask',
#  'abassi',
#  'abassin',
#  'abastard',
#  'abastardize',
#  'abastral',
#  'abatable',
#  'abatage',
#  'abate',
#  'abated',
#  'abatement',
#  'abatements',
#  'abater',
#  'abaters',
#  'abates',
#  'abatic',
#  'abating',
#  'abatis',
#  'abatised',
#  'abatises',
#  'abatjour',
#  'abatjours',
#  'abaton',
#  'abator',
#  'abators',
#  'abattage',
#  'abattis',
#  'abattised',
#  'abattises',
#  'abattoir',
#  'abattoirs',
#  'abattu',
#  'abattue',
#  'abatua',
#  'abature',
#  'abaue',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abay',
#  'abayah',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacies',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbandono',
#  'abbas',
#  'abbasi',
#  'abbasid',
#  'abbassi',
#  'abbasside',
#  'abbate',
#  'abbatial',
#  'abbatical',
#  'abbatie',
#  'abbaye',
#  'abbe',
#  'abbes',
#  'abbess',
#  'abbesses',
#  'abbest',
#  'abbevillian',
#  'abbey',
#  'abbeys',
#  'abbeystead',
#  'abbeystede',
#  'abbie',
#  'abboccato',
#  'abbogada',
#  'abbot',
#  'abbotcies',
#  'abbotcy',
#  'abbotnullius',
#  'abbotric',
#  'abbots',
#  'abbotship',
#  'abbotships',
#  'abbott',
#  'abbozzo',
#  'abbr',
#  'abbrev',
#  'abbreviatable',
#  'abbreviate',
#  'abbreviated',
#  'abbreviately',
#  'abbreviates',
#  'abbreviating',
#  'abbreviation',
#  'abbreviations',
#  'abbreviator',
#  'abbreviators',
#  'abbreviatory',
#  'abbreviature',
#  'abbroachment',
#  'abby',
#  'abc',
#  'abcess',
#  'abcissa',
#  'abcoulomb',
#  'abd',
#  'abdal',
#  'abdali',
#  'abdaria',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdicated',
#  'abdicates',
#  'abdicating',
#  'abdication',
#  'abdications',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdom',
#  'abdomen',
#  'abdomens',
#  'abdomina',
#  'abdominal',
#  'abdominales',
#  'abdominalia',
#  'abdominalian',
#  'abdominally',
#  'abdominals',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abduced',
#  'abducens',
#  'abducent',
#  'abducentes',
#  'abduces',
#  'abducing',
#  'abduct',
#  'abducted',
#  'abducting',
#  'abduction',
#  'abductions',
#  'abductor',
#  'abductores',
#  'abductors',
#  'abducts',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedaire',
#  'abecedaria',
#  'abecedarian',
#  'abecedarians',
#  'abecedaries',
#  'abecedarium',
#  'abecedarius',
#  'abecedary',
#  'abed',
#  'abede',
#  'abedge',
#  'abegge',
#  'abeigh',
#  'abel',
#  'abele',
#  'abeles',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelmosks',
#  'abelmusk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abend',
#  'abends',
#  'abenteric',
#  'abepithymia',
#  'aberdavine',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberduvine',
#  'aberia',
#  'abernethy',
#  'aberr',
#  'aberrance',
#  'aberrancies',
#  'aberrancy',
#  'aberrant',
#  'aberrantly',
#  'aberrants',
#  'aberrate',
#  'aberrated',
#  'aberrating',
#  'aberration',
#  'aberrational',
#  'aberrations',
#  'aberrative',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncate',
#  'aberuncator',
#  'abesse',
#  'abessive',
#  'abet',
#  'abetment',
#  'abetments',
#  'abets',
#  'abettal',
#  'abettals',
#  'abetted',
#  'abetter',
#  'abetters',
#  'abetting',
#  'abettor',
#  'abettors',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyances',
#  'abeyancies',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abfarads',
#  'abhenries',
#  'abhenry',
#  'abhenrys',
#  'abhinaya',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorred',
#  'abhorrence',
#  'abhorrences',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrers',
#  'abhorrible',
#  'abhorring',
#  'abhors',
#  'abhorson',
#  'abib',
#  'abichite',
#  'abidal',
#  'abidance',
#  'abidances',
#  'abidden',
#  'abide',
#  'abided',
#  'abider',
#  'abiders',
#  'abides',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abiegh',
#  'abience',
#  'abient',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abietite',
#  'abiezer',
#  'abigail',
#  'abigails',
#  'abigailship',
#  'abigeat',
#  'abigei',
#  'abigeus',
#  'abilao',
#  'abilene',
#  'abiliment',
#  'abilitable',
#  'abilities',
#  'ability',
#  'abilla',
#  'abilo',
#  'abime',
#  'abintestate',
#  'abiogeneses',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abioses',
#  'abiosis',
#  'abiotic',
#  'abiotical',
#  'abiotically',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritated',
#  'abirritating',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abit',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjections',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudged',
#  'abjudging',
#  'abjudicate',
#  'abjudicated',
#  'abjudicating',
#  'abjudication',
#  'abjudicator',
#  'abjugate',
#  'abjunct',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjurations',
#  'abjuratory',
#  'abjure',
#  'abjured',
#  'abjurement',
#  'abjurer',
#  'abjurers',
#  'abjures',
#  'abjuring',
#  'abkar',
#  'abkari',
#  'abkary',
#  'abkhas',
#  'abkhasian',
#  'abl',
#  'ablach',
#  'ablactate',
#  'ablactated',
#  'ablactating',
#  'ablactation',
#  'ablaqueate',
#  'ablare',
#  'ablastemic',
#  'ablastin',
#  'ablastous',
#  'ablate',
#  'ablated',
#  'ablates',
#  'ablating',
#  'ablation',
#  'ablations',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablatively',
#  'ablatives',
#  'ablator',
#  'ablaut',
#  'ablauts',
#  'ablaze',
#  'able',
#  'abled',
#  'ableeze',
#  'ablegate',
#  'ablegates',
#  'ablegation',
#  'ablend',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ablepsy',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ables',
#  'ablesse',
#  'ablest',
#  'ablet',
#  'ablewhackets',
#  'ablings',
#  'ablins',
#  'ablock',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'abluents',
#  'ablush',
#  'ablute',
#  'abluted',
#  'ablution',
#  'ablutionary',
#  'ablutions',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abmhos',
#  'abmodalities',
#  'abmodality',
#  'abn',
#  'abnaki',
#  'abnegate',
#  'abnegated',
#  'abnegates',
#  'abnegating',
#  'abnegation',
#  'abnegations',
#  'abnegative',
#  'abnegator',
#  'abnegators',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalcies',
#  'abnormalcy',
#  'abnormalise',
#  'abnormalised',
#  'abnormalising',
#  'abnormalism',
#  'abnormalist',
#  'abnormalities',
#  'abnormality',
#  'abnormalize',
#  'abnormalized',
#  'abnormalizing',
#  'abnormally',
#  'abnormalness',
#  'abnormals',
#  'abnormities',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'aboardage',
#  'abobra',
#  'abococket',
#  'abodah',
#  'abode',
#  'aboded',
#  'abodement',
#  'abodes',
#  'aboding',
#  'abody',
#  'abogado',
#  'abogados',
#  'abohm',
#  'abohms',
#  'aboideau',
#  'aboideaus',
#  'aboideaux',
#  'aboil',
#  'aboiteau',
#  'aboiteaus',
#  'aboiteaux',
#  'abolete',
#  'abolish',
#  'abolishable',
#  'abolished',
#  'abolisher',
#  'abolishers',
#  'abolishes',
#  'abolishing',
#  'abolishment',
#  'abolishments',
#  'abolition',
#  'abolitionary',
#  'abolitionise',
#  'abolitionised',
#  'abolitionising',
#  'abolitionism',
#  'abolitionist',
#  'abolitionists',
#  'abolitionize',
#  'abolitionized',
#  'abolitionizing',
#  'abolla',
#  'abollae',
#  'aboma',
#  'abomas',
#  'abomasa',
#  'abomasal',
#  'abomasi',
#  'abomasum',
#  'abomasus',
#  'abomasusi',
#  'abominability',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abominated',
#  'abominates',
#  'abominating',
#  'abomination',
#  'abominations',
#  'abominator',
#  'abominators',
#  'abomine',
#  'abondance',
#  'abongo',
#  'abonne',
#  'abonnement',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginals',
#  'aboriginary',
#  'aborigine',
#  'aborigines',
#  'aborning',
#  'aborsement',
#  'aborsive',
#  'abort',
#  'aborted',
#  'aborter',
#  'aborters',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'aborting',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortionists',
#  'abortions',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortogenic',
#  'aborts',
#  'abortus',
#  'abortuses',
#  'abos',
#  'abote',
#  'abouchement',
#  'aboudikro',
#  'abought',
#  'aboulia',
#  'aboulias',
#  'aboulic',
#  'abound',
#  'abounded',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'abounds',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'abovementioned',
#  'aboveproof',
#  'aboves',
#  'abovesaid',
#  'abovestairs',
#  'abow',
#  'abox',
#  'abp',
#  'abr',
#  'abracadabra',
#  'abrachia',
#  'abrachias',
#  'abradable',
#  'abradant',
#  'abradants',
#  'abrade',
#  'abraded',
#  'abrader',
#  'abraders',
#  'abrades',
#  'abrading',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrased',
#  'abraser',
#  'abrash',
#  'abrasing',
#  'abrasiometer',
#  'abrasion',
#  'abrasions',
#  'abrasive',
#  'abrasively',
#  'abrasiveness',
#  'abrasives',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abray',
#  'abrazite',
#  'abrazitic',
#  'abrazo',
#  'abrazos',
#  'abreact',
#  'abreacted',
#  'abreacting',
#  'abreaction',
#  'abreactions',
#  'abreacts',
#  'abreast',
#  'abreed',
#  'abrege',
#  'abreid',
#  'abrenounce',
#  'abrenunciate',
#  'abrenunciation',
#  'abreption',
#  'abret',
#  'abreuvoir',
#  'abri',
#  'abrico',
#  'abricock',
#  'abricot',
#  'abridgable',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridgement',
#  'abridgements',
#  'abridger',
#  'abridgers',
#  'abridges',
#  'abridging',
#  'abridgment',
#  'abridgments',
#  'abrim',
#  'abrin',
#  'abrine',
#  'abris',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogated',
#  'abrogates',
#  'abrogating',
#  'abrogation',
#  'abrogations',
#  'abrogative',
#  'abrogator',
#  'abrogators',
#  'abroma',
#  'abronia',
#  'abrood',
#  'abrook',
#  'abrosia',
#  'abrosias',
#  'abrotanum',
#  'abrotin',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abrupter',
#  'abruptest',
#  'abruptio',
#  'abruption',
#  'abruptiones',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'abs',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscam',
#  'abscess',
#  'abscessed',
#  'abscesses',
#  'abscessing',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscised',
#  'abscises',
#  'abscising',
#  'abscisins',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscissas',
#  'abscisse',
#  'abscissin',
#  'abscission',
#  'abscissions',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconders',
#  'absconding',
#  'absconds',
#  'absconsa',
#  'abscoulomb',
#  'abscound',
#  'absee',
#  'abseil',
#  'abseiled',
#  'abseiling',
#  'abseils',
#  'absence',
#  'absences',
#  'absent',
#  'absentation',
#  'absented',
#  'absentee',
#  'absenteeism',
#  'absentees',
#  'absenteeship',
#  'absenter',
#  'absenters',
#  'absentia',
#  'absenting',
#  'absently',
#  'absentment',
#  'absentminded',
#  'absentmindedly',
#  'absentmindedness',
#  'absentness',
#  'absents',
#  'absey',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinth',
#  'absinthe',
#  'absinthes',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthiated',
#  'absinthiating',
#  'absinthic',
#  'absinthiin',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absinthole',
#  'absinths',
#  'absis',
#  'absist',
#  'absistos',
#  'absit',
#  'absmho',
#  'absohm',
#  'absoil',
#  'absolent',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absoluter',
#  'absolutes',
#  'absolutest',
#  'absolution',
#  'absolutions',
#  'absolutism',
#  'absolutist',
#  'absolutista',
#  'absolutistic',
#  'absolutistically',
#  'absolutists',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolved',
#  'absolvent',
#  'absolver',
#  'absolvers',
#  'absolves',
#  'absolving',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbance',
#  'absorbancy',
#  ...]

# %%
# Define signature function (a list of all letters in a word)
def signature(word):
    signature = ''.join(sorted(word)) # Sort all letters of word and 'join' with blank character
    return signature

# %%
wordsBySig = collections.defaultdict(set) # this adds a set to the dictionary every time a new word is iterated
for word in words:
    wordsBySig[signature(word)].add(word)

# %%
anagramsBySig = {signature: wordset for signature, wordset in wordsBySig.items() if len(wordset) > 1}

# %%
# Define FASTER anagram finder -- returns all possible anagrams of a word as a list
def fasterAnagramFinder(myword):
    mysig = signature(myword)
    
    try:
        return anagramsBySig[mysig]
    except KeyError:
        print('This word doesn\'t appear to be in the dictionary. Hmmm.')

# %%
fasterAnagramFinder('dfdkjfd')
# Out:
# This word doesn't appear to be in the dictionary. Hmmm.

# %%
# What are the longest anagrams?
sorted(anagramsBySig.keys(), key = len, reverse= True)
# Out:
# ['aceefhhillmnoooorrrttu',
#  'ccddeehlmnooooossttuyy',
#  'acddeehiimmnoopprrruuy',
#  'aaaaccghiillmnooooptt',
#  'acghhhhilmooooopprrtt',
#  'aaccddeeemnnoooprttuy',
#  'aaabegghilllnoooprssy',
#  'aceehhiilmnnooorrrttt',
#  'aaccghiiilmnoooopsty',
#  'acceeeeeghillmnnnoop',
#  'aaabeggillllnooorssy',
#  'aaaccghiilmnooooptt',
#  'aacccghiiilllnooopt',
#  'aceeeghiiilmnnnopst',
#  'aaegghmooooprssstty',
#  'bceiiiilnnoorrtttvy',
#  'aacccdeehiiinopprrr',
#  'accghhiilloooppssyy',
#  'abceehhlmmnoooorrt',
#  'aaccdhmmnoooorrsxy',
#  'cdehiiiiinooorrstt',
#  'accghhhinoooopprrt',
#  'ceeeeehlmmoorrrttt',
#  'addeiimmooopsstvyy',
#  'aaeeeghlmmnoorrttv',
#  'aadeeehhiknorrsttx',
#  'aagghiilnnoprrstyy',
#  'aaceghlmnooorrttyy',
#  'acceghillnoooprsuy',
#  'aacghhiilloooppsty',
#  'aaccghhlmooopprsyy',
#  'aacdeeehiillmntty',
#  'aaaabchiimnoprrst',
#  'aaccceeiilloorssu',
#  'aceeghiiilmnnopst',
#  'bceeegiiimnnorrst',
#  'aacccceehhiilmmno',
#  'acccehhilmoopprty',
#  'acghhhilmoooprrty',
#  'acghhhmoooopprrty',
#  'acghhhnoooopprrty',
#  'aciiilmnnoosstttu',
#  'acdegiilmoooopsuy',
#  'aacceeegillmnortt',
#  'aceeehiillmnopsty',
#  'aacdeehhiknoorstx',
#  'adehhmnoooprrtuxy',
#  'aaehlmoooprrsttyy',
#  'ceehmmmooorsttyyy',
#  'aaaegghllnnoprryy',
#  'eehhiilmnoooprstt',
#  'aceghhimooopprrrt',
#  'accghhiimooopprrt',
#  'ccceeimooopprrsst',
#  'aeeeiimnnoprrsstt',
#  'aaceilnnnnooorstv',
#  'aacdeeiillopprrru',
#  'aabdeeiilmnnotxz',
#  'acdhhiinoorrrstt',
#  'aaacdghiiooprrtu',
#  'abccghiillooopsy',
#  'aaccceelnooorrsu',
#  'aaaacccimnoorrst',
#  'acghhhnoooopprrt',
#  'acfgiiimnnoorstu',
#  'aaccdeeillmnorty',
#  'accdefhiinorrryy',
#  'accdefhinoorrryy',
#  'aabcfimmooorrsxy',
#  'aceeghhloopprsty',
#  'aeghhhilooopprty',
#  'aeehhmmnoooprtux',
#  'bceeiilnnoorrttv',
#  'aceeiiilnnossttv',
#  'aaellmnooopprsty',
#  'aghhhilooopprtty',
#  'aacghhmooopprrty',
#  'ceeeegillmmnnooy',
#  'acghhimooopprrst',
#  'acghhimooopprrty',
#  'cehilmnoopprrsuu',
#  'acceiilmooopprtt',
#  'aaaeilmoopqrsstu',
#  'acghhiiloooppsty',
#  'aaceeiinnnoppttt',
#  'aaceghillopprrty',
#  'aghhiiinnoprrsty',
#  'aeeghhooopprrstt',
#  'aceeghhiloopprtt',
#  'cghhiloooppssyyy',
#  'cceghhlnooopstyy',
#  'aeeeglmooprrrtuy',
#  'aacccillorrstuuu',
#  'aacchilmnnoopsst',
#  'cceeeeloopprsstt',
#  'cehiiooprrsssttt',
#  'aaabdgiilmnnoov',
#  'aabcdeiilmnoosv',
#  'accceeiloorsttu',
#  'aacghiilllmorty',
#  'aaceiiillmnostu',
#  'aeiilnooprsstty',
#  'aaadghiooprrtuy',
#  'aabeghhmooprrrt',
#  'bcghiilooopssty',
#  'abccgiiilloooos',
#  'aaacccimnoorrss',
#  'acccehhiilmopsy',
#  'aaceeghimnoprrt',
#  'aabceilmnootttu',
#  'acceeiinnoorsss',
#  'aceiimnnoorsstv',
#  'aceiinnoorssttv',
#  'cciimnnoorssttu',
#  'cehiiorrsstttuy',
#  'aacddeeiloprtty',
#  'adeeimnoorrsstu',
#  'adeiilnorrssttx',
#  'accceeiiilmssst',
#  'acceeegilmnortt',
#  'aacccdeeillnopy',
#  'aeegiinorrssttt',
#  'adeehhilmnoopst',
#  'accfiilnoooprtt',
#  'aaceeggillmnoty',
#  'aacefgiiimnnort',
#  'aacghillmnoopry',
#  'aadeeehhnorrttx',
#  'bceeiiilmpprrst',
#  'beeeiilmnprssss',
#  'eefiinoooprrrst',
#  'eeeiinnoprrsstv',
#  'aeiilnnnorsstuv',
#  'ehhilmnoooprtty',
#  'aacghhmooopprrt',
#  'eegiiilmmnnosty',
#  'acghhimooopprrt',
#  'ccehimoooopprst',
#  'acdeeiimmoorrrt',
#  'addeeimnnrrsstu',
#  'eeeffinnnosssuv',
#  'aaeeilmoopprrtt',
#  'aaceeiiloprrstv',
#  'aghhiloooppstyy',
#  'acghhloooppstyy',
#  'aceehhlnooppssu',
#  'aeeghhloopprtty',
#  'aghhoooppprttyy',
#  'aehmnooopprtuxy',
#  'eeiooopprrrsstu',
#  'aeiimnnoprrssst',
#  'cdeeiimooprsstu',
#  'aadeeghiloprrty',
#  'aceefiiinorrstv',
#  'acegiilnosstttu',
#  'ceeeeelooprsstt',
#  'abeeelnorrrsttv',
#  'abeeeilnnrsstuv',
#  'aabceeelnnrsstu',
#  'aacddehmnnooor',
#  'aaaacdemnoorst',
#  'aaadiiilnnrttu',
#  'aacdghimnnooor',
#  'aaacchiilnrstt',
#  'aeefiinnoorrrt',
#  'aeeinooprrrstu',
#  'acehiinnoprsst',
#  'aaeilmnnnorsst',
#  'aaciiimnoossst',
#  'aacciilloprsuy',
#  'aaadghiooprrtu',
#  'abcelmoossttuy',
#  'bcdfhilooorruy',
#  'aaacccimnoorrs',
#  'aaceiilnnorstt',
#  'abcefiiiilrtty',
#  'accefiiinorstt',
#  'accceeiilorsvv',
#  'acchiillnooprt',
#  'abcdfhimnooorr',
#  'aaceilnnoorstv',
#  'aceeinoorrsstv',
#  'acdiilnnooosst',
#  'ceiinnoorstttu',
#  'abceeloorrsttv',
#  'cehinooprsssty',
#  'aadeeenorrsttt',
#  'aadeeinnostttu',
#  'acdegiillooprt',
#  'adegiiinnorstt',
#  'adellnoorrstvy',
#  'addeejjlnnoouu',
#  'accdeeilmnorty',
#  'adeeiiilorrstz',
#  'acceegillnorty',
#  'cceeehilmorrtt',
#  'accdeeilnopsty',
#  'ehhillnoprrtyy',
#  'aeiiinoprstttx',
#  'aaefilnooprrtt',
#  'aeflmnoooprrtt',
#  'aaccghilnopsvy',
#  'eeegiimnoprsss',
#  'degghilooorsty',
#  'adeeghnnorssst',
#  'adeehhhillmoor',
#  'aceeghillooprt',
#  'dehhinooprrssy',
#  'aceghilllopryy',
#  'beiiiilmprssty',
#  'eeeiimnprssssv',
#  'aceegilmnnoort',
#  'aeeiillnnoprtt',
#  'adeeeeimnprrtt',
#  'aceeiilnnorstt',
#  'aeiiinnoprrstt',
#  'acegilllmoorty',
#  'cdeiiloorrssuu',
#  'eeellnrssssstu',
#  'accdehiilmopsy',
#  'beehiilmoprstt',
#  'eeeeimnprrrsst',
#  'aaciillnrsttuy',
#  'eehiilnopprsty',
#  'cehinooprsssuy',
#  'acdeeinnnoorst',
#  'aaaacdiillprsy',
#  'aceeeeinprsstt',
#  'aaeegiilnnoprv',
#  'aabeilnoprrttu',
#  'aaceghilopprrt',
#  'acegilllooprty',
#  'aaelmoopqrsstu',
#  'aehhiilnopprst',
#  'aadghimoooprrt',
#  'aeeghhloopprtt',
#  'ceeeilnoprsstu',
#  'aceeilloprrsuv',
#  'aceilnnoooprst',
#  'aaeeiilnoprrtz',
#  'eeeeinnprssstv',
#  'adeinooopprrtt',
#  'eiinoopprssstu',
#  'aegimmnooprstu',
#  'ahinnopprrtuux',
#  'adeeehilnooprt',
#  'aaeiiilnorttvz',
#  'adefiilnoorttu',
#  'aabceelorrrstv',
#  'aeeilnoorrsstu',
#  'aaceiiilnosttt',
#  'ccgiiilnossttu',
#  'abefllnoopsstu',
#  'abdeeghinnrrtu',
#  'aaaiimnnnorstt',
#  'aabeeelmnnnssu',
#  'abdefiiilnntuy',
#  'ceeeilnpprtuvy',
#  'acceemnorsttu',
#  'aadehlmmnoopy',
#  'aaacdemnoorss',
#  'aaacehilmnoor',
#  'aaaceghiloprr',
#  'aacefiiilmnot',
#  'aacehhiimprtt',
#  'aacfiiilmnopt',
#  'acghiiilnoost',
#  'aaaegikmnoort',
#  'aciiilmnnortu',
#  'aaceiilnprstt',
#  'abcciinorsttu',
#  'acfiiinooprst',
#  'aeefginorrstu',
#  'aehiiorrssttt',
#  'aceeloorrstuu',
#  'aeeeinnsstttv',
#  'aeehioorssttu',
#  'abdeeelnrssss',
#  'beeeflnnooruz',
#  'bcghilooopsyy',
#  'abcceilmostty',
#  'abhiilnoopstt',
#  'aaabccfhiilor',
#  'abcccceiloruv',
#  'acceehilmoprt',
#  'acdehloooppsu',
#  'accefiiinortt',
#  'acceefiiirttv',
#  'accefiiorrtty',
#  'accdeiloorrsv',
#  'aacccefiilorv',
#  'aabcceiillorv',
#  'aabceeehlnsst',
#  'aceeehilmorst',
#  'accdhlnooorst',
#  'acdhilmnooopr',
#  'acdhmmnooorxy',
#  'ccciiimnorssu',
#  'ceeiilnoorstt',
#  'cciiloooprstt',
#  'acceiilmmorst',
#  'ceiimmnoorsss',
#  'acciilmmnostu',
#  'ceeiimnooprtt',
#  'ciimmnoooprss',
#  'acdeinnnoosst',
#  'acdlmnooostuy',
#  'cceiimnnnoost',
#  'aceinnoorsstv',
#  'aceeinoorrstv',
#  'acdeeiinorstv',
#  'aceennoorrstu',
#  'aceeiinorrstt',
#  'acddeemnnortu',
#  'acdeenorrsttu',
#  'ceeeilmnrssss',
#  'acgiilnnorruu',
#  'acemooprsttty',
#  'aclmorssttuuu',
#  'ceiilopssttyy',
#  'acdeloprsttuy',
#  'aacdeehiilnop',
#  'addeegimnnnss',
#  'adeiimnnooprt',
#  'aadeeiilnortz',
#  'deeiiinoqrstu',
#  'cdeeeilmorrst',
#  'deehilprrsuuz',
#  'adegiimooprst',
#  'acdehilloppsu',
#  'degiilooprstt',
#  'acdiiimnorrst',
#  'adeegiiilmstt',
#  'deghiiinrsstu',
#  'acdeeimnorstu',
#  'acdeilmnortuy',
#  'aacceillnstuy',
#  'acccdeeilnopy',
#  'adeeiinorrstt',
#  'aacdeiilmopry',
#  'deehhimnoopst',
#  'aceghilllooty',
#  'aeiilnoopsttx',
#  'eeiimnoprsssx',
#  'abfilnooorrtt',
#  'aeggilnnnooru',
#  'aaceghioprstt',
#  'aceghinoprrst',
#  'aegiinnorrtuy',
#  'cdegghilooory',
#  'acegiilnosttu',
#  'acdghinoooprt',
#  'aacghilmnoopr',
#  'aaadeglnnprrt',
#  'aacgghilloopr',
#  'aaghinoprrstu',
#  'aaceehilmpsty',
#  'aaaeeghilmopt',
#  'aceehhinopprt',
#  'adehhloprstuy',
#  'ghiiloopsssty',
#  'acceiilmnoort',
#  'ceefiimnoprst',
#  'aegiimnnoprst',
#  'aeiimnnooprst',
#  'eiiimmnoprsss',
#  'abcceeiilnnov',
#  'acilnnnnoosty',
#  'aacdeilllmnou',
#  'aiiinnnoosttv',
#  'aghhinooprrty',
#  'cegiilnoosstt',
#  'aciilnnorsttu',
#  'aaceiilnnortt',
#  'ceeiinnoprstt',
#  'aceiiimnnorrt',
#  'cceefiiinprst',
#  'aaceilnrrstuv',
#  'beeiilnnorsst',
#  'aegiiinnosttv',
#  'aaachllmnorsy',
#  'aaeellnorrttv',
#  'aabeiilmnortz',
#  'aaciillmortty',
#  'aeghlmnooopsu',
#  'aaeegillmnops',
#  'achimnooprrst',
#  'aceilmooprstu',
#  'ceeiimnopprst',
#  'eggiimnossstu',
#  'eeiilmnorstuy',
#  'ceeehimnoprst',
#  'aaccdehinoprr',
#  'eeffilnnosuvy',
#  'aaellnnnoprty',
#  'achiimnnoortt',
#  'aeghhiooprrst',
#  'aceeilmoorstt',
#  'acceeilorrtuv',
#  'aceeinorsssuv',
#  'aaehiinpprrst',
#  'aaciiopprrstt',
#  'aaehnnoprstty',
#  'aaciilloprtty',
#  'acdeeiimnoprt',
#  'aabeilmnoprtu',
#  'aabelmoprrtuy',
#  'acdeiiiloprst',
#  'aceiilnoprsst',
#  'aghhinoopprst',
#  'ceehilnnopprs',
#  'aehmnnoopptuy',
#  'admoooopssttu',
#  'cdeeiinoprrst',
#  'aaeiloopprrrt',
#  'aceeooprrsttt',
#  'dehiloopprstu',
#  'abddeeimoopsu',
#  'acchimoopssty',
#  'aaciillnprtuy',
#  'aceeiimoppsty',
#  'cceeiimoppsty',
#  'aaceggilnortu',
#  'adeeginorrrtt',
#  'ceiinnorrsttu',
#  'aeegiinnorrtt',
#  'aeeghinrrsstt',
#  'eeeghnnrrsstt',
#  'eiinoopprsstu',
#  'aaiiilnorttuz',
#  'aaccfiiinorst',
#  'abccillorstuy',
#  'aeeelnssssstt',
#  'ddeeeinnprstu',
#  'deeeinnprrstu',
#  'aabeiilmnntuy',
#  'abceefiilnrtu',
#  'abceelnnorsuv',
#  'beeiilmnprssu',
#  'beiilmnprssuy',
#  'abegiilmnnruz',
#  'ceeeiklnprstu',
#  'bceeilnpsstuu',
#  'aacegiilnosvv',
#  'acefiiinorstv',
#  'abiiilmnoost',
#  'aacceiilmrst',
#  'accehilmoprs',
#  'acceemnorttu',
#  'aaccehilnort',
#  'aacchiimnort',
#  'acdhiiloopsu',
#  'aaccillorsty',
#  'aaceinnoprtt',
#  'aaccelmntuuu',
#  'aacdemnoosty',
#  'aabdefimnoor',
#  'aaacdemnoors',
#  'adiimnooprss',
#  'acdeinooprrt',
#  'aadegilnrttu',
#  'aaaceilnnrst',
#  'aceghillnoot',
#  'aabeiillrtty',
#  'aaceilnorstt',
#  'adiilnosttuu',
#  'aaegiilmnort',
#  'aaeehlmnoorr',
#  'aaeehhimprtt',
#  'ahimoopprstu',
#  'aacdeilmnost',
#  'aaceghimnopr',
#  'aabfgiimnoor',
#  'aeginnoorstu',
#  'aaiimnnnnoot',
#  'aaeilmnnrtuy',
#  'aeeeinprrttt',
#  'aaceiinnortt',
#  'aaceeiinrttv',
#  'aacciilnortt',
#  'acfiiinnortt',
#  'aiimnooqsttu',
#  'aegiimnnorst',
#  'aeinnnorsttu',
#  'aaceiilnprtt',
#  'acehiinnoptt',
#  'aaeeinoprstt',
#  'aaiilnorstty',
#  'aaciilnoprtt',
#  'aachiilmoprs',
#  'aachiiloprst',
#  'aaceehioprst',
#  'aeeginooqsuu',
#  'aceeehorrrsv',
#  'aaeiilnorstt',
#  'aacegiinnrst',
#  'aeeinoprrsty',
#  'aeeillmnrrty',
#  'abdehiiooprs',
#  'abehiimorsuv',
#  'aabceillprry',
#  'bcgiiloooosy',
#  'abeiiilnostt',
#  'abcceilloost',
#  'aabceehloprr',
#  'aabcdhinoopr',
#  'aabeeehkrrtw',
#  'aabcdeorrsst',
#  'abdehmoorrty',
#  'aacccdeimnoo',
#  'acceiillnost',
#  'acdeiilmortt',
#  'aaaciilnnost',
#  'accelmopstuy',
#  'abcddehiorry',
#  'aaceiimnrsst',
#  'accehiilorst',
#  'aacdeflmooru',
#  'aaacdellortu',
#  'aaceiinorstu',
#  'acdelnoorrst',
#  'aceeillnnort',
#  'aacceehlortt',
#  'accefiiorrtt',
#  'accdeiinorvy',
#  'acdeehiinort',
#  'aaceehlmprst',
#  'aceehlnoprss',
#  'aacceehirrst',
#  'cdehiiooprst',
#  'accehiilmotv',
#  'cehimmooprst',
#  'acchiimnorst',
#  'chhiiooprsst',
#  'acehiilnnoor',
#  'aacehilmnoor',
#  'cddehiilooor',
#  'accehmoortty',
#  'cchhiilmoort',
#  'acchimnnoort',
#  'acghhoprrsyy',
#  'ccilmorrsuuu',
#  'aceiilnrsstt',
#  'ccciilnnooot',
#  'aciiilnoostt',
#  'accdeiilnnot',
#  'cceeillnoort',
#  'aciillnoosst',
#  'ceelnoprrtuy',
#  'aacghilooprr',
#  'aaceilmmnort',
#  'aaciimmorsst',
#  'cdeiimmnooss',
#  'ceiimmnoorss',
#  'cehimmnooprs',
#  'aceilmmnorsu',
#  'aceeemnoprtt',
#  'cdeeehmnoprr',
#  'cceeginnnort',
#  'acceennorstt',
#  'ccegiinnortz',
#  'cceeinnoorss',
#  'cdeiinnoorst',
#  'acceinnnooss',
#  'aacceinnorst',
#  'aceinnoorstv',
#  'aceeinorstvv',
#  'acdeiilmnost',
#  'acdeilnoosst',
#  'aceinnorrsst',
#  'aceimnnnostt',
#  'abcinnoorttu',
#  'ceeinnnoortv',
#  'acgilnooprst',
#  'acghioopprst',
#  'aaceillnoort',
#  'acceinooprtu',
#  'aceilooprrst',
#  'cceeinoorrrt',
#  'acelnoorsstt',
#  'acceenorrttu',
#  'accehmnorrtu',
#  'acdegnorrtuu',
#  'acdeeilnortu',
#  'acdeelnoprtu',
#  'ceinnooprttu',
#  'ceelnooprstu',
#  'acdeehnorstu',
#  'ceeinoprsstu',
#  'aceinnorsttu',
#  'acdennorsttu',
#  'cehiioprrstu',
#  'aceeeinrsstv',
#  'cdehiioprrst',
#  'aceiimmnorst',
#  'ceeeimorrstt',
#  'ccdhiioorrty',
#  'acegilnorrtu',
#  'acdeeinrttuv',
#  'cehmoossstuu',
#  'abcfimoorsty',
#  'acdeeiilmrst',
#  'acdeiilnnost',
#  'abdefiiilnty',
#  'adeeiilnrsuz',
#  'acdeeeilnsst',
#  'adeiiilmnott',
#  'adeeegimnrst',
#  'adeeegimnrtz',
#  'aadeeilllmpr',
#  'acddeeimorst',
#  'adeemnorrstt',
#  'adeeiinnnotz',
#  'adeiimnnnoot',
#  'adeeiimnnotv',
#  'aadeilnnoott',
#  'adegiillnntu',
#  'adegillnnotu',
#  'adeeiiloprst',
#  'adeiilnoopst',
#  'acdeeiinoprt',
#  'adeegmmoprrr',
#  'deehiilnqrsu',
#  'aadeiilnortv',
#  'adeeiimrsstt',
#  'adeehmnooprt',
#  'deeeiinrsstz',
#  'adegiilnprsy',
#  'adeiinnosstt',
#  'deefilrrsuuz',
#  'acdeginnrttu',
#  'acdeeinoprtu',
#  'deilmnoopsty',
#  'acdeeioprstu',
#  'addeeinrstuv',
#  'acdiilnnostu',
#  'cdeiinnorstu',
#  'cdeeeinrssst',
#  'acdeiinoprst',
#  'acdiilnopstu',
#  'adehiimnorss',
#  'adeeeimprstt',
#  'acdfiiimnoot',
#  'aadelloorrst',
#  'addenoorrstv',
#  'adelnoorrstv',
#  'aeeeilmnrtty',
#  'aacehillmpty',
#  'aceeemnnrstt',
#  'ceeennorrstu',
#  'ceeegiinrstt',
#  'eeeghilnnrst',
#  'eemnnoorsssu',
#  'eegiinnprrst',
#  'aeegiinnnrtt',
#  'acehiinssttu',
#  'eegilmnooost',
#  'aeeimnnorstu',
#  'aaeeiilnprst',
#  'aaceehiilprt',
#  'aeeghhoprrty',
#  'aeehiinorttz',
#  'cceehinnortt',
#  'aaceeinortvx',
#  'aaeeinoprstx',
#  'aceiinoorstx',
#  'beehiiinortx',
#  'eeeeimnprrtx',
#  'aeiilnoopstx',
#  'aaeiillmnrtx',
#  'aeeeflmnssss',
#  'abefiilmoort',
#  'abefimnoorru',
#  'eeffgilnorrw',
#  'adefinnoortu',
#  'aaaegllnnott',
#  'aacghioprstt',
#  'degghloooryy',
#  'aabgilllooss',
#  'defgiinoorsu',
#  'aghimnooprst',
#  'acghhinooppr',
#  'aabdehhirrst',
#  'abchiilnoopt',
#  'ahhooopprstu',
#  'aceehiimrstt',
#  'aceehiinortt',
#  'aceehoprrstu',
#  'eeghnoorstuy',
#  'acehilmoopty',
#  'aadehilmorru',
#  'achiilmorstu',
#  'eehlnrsssstu',
#  'adefhlorstuy',
#  'achimoopstty',
#  'aceehhoprtty',
#  'aehhoprsttyy',
#  'aaciiilprstt',
#  'dhiimoooprsu',
#  'abeeeilmnprt',
#  'abeeilmnprty',
#  'adeeimnoprst',
#  'aceimnnoprtu',
#  'ceiiimnoprss',
#  'eeiilmprssvy',
#  'aacgiiinnttv',
#  'aaciiinnottv',
#  'aadeeilnrttu',
#  'abceilmnoptu',
#  'abcilmnoptuy',
#  'ceiinnnosstt',
#  'ddeefiiinntu',
#  'abdeeiilnprv',
#  'cdeiiinnorst',
#  'cdeeiilnrsty',
#  'aabbeiilnnot',
#  'aciilnnoostu',
#  'aaceilnoprtu',
#  'aeiimnnorsst',
#  'aceeinoprstt',
#  'aceiilnoprst',
#  'ceeiinnorsst',
#  'cdeeilnoprtu',
#  'acdeeeilnrrt',
#  'ceiiiimnrstt',
#  'aeeimnnnortt',
#  'ceeinooprrtt',
#  'aeeeillnprtt',
#  'aeeilnoprstt',
#  'eeeinprrrstt',
#  'cdeeinoprrtu',
#  'aeeiinrstttu',
#  'aeiinnorsttt',
#  'eeiinnnorttv',
#  'aegiilnnortt',
#  'aiillnnootuv',
#  'cdeeiiimorst',
#  'aabeiilnorrt',
#  'aceeeinnprrt',
#  'beeeiilrrrsv',
#  'aaccchiiorss',
#  'aeiiimnosttz',
#  'aeehiiknssst',
#  'aceilnooprtt',
#  'adeeeggilnrt',
#  'aadeiiloprsu',
#  'aacehilnopst',
#  'aehhiilnoprt',
#  'acegillmoort',
#  'adgiillnnotu',
#  'aacehilmpsty',
#  'aacgillmoost',
#  'aabeeelmnruv',
#  'aeegimnnoruv',
#  'aaeghlmnrstu',
#  'aceeeilmnpst',
#  'aeghimooprst',
#  'aeeelmnsssst',
#  'aciilmnorstu',
#  'aacdeilmrttu',
#  'adeeilmnortv',
#  'acdeehimnrrs',
#  'aacehilmoprt',
#  'aceilmmnoort',
#  'eeilmooprsst',
#  'accehilmopry',
#  'ceimooprrstu',
#  'ceeiimmnorss',
#  'egiimnoprrst',
#  'adiiimnorstt',
#  'acdeimnoosty',
#  'hllmnooopsuy',
#  'chimmnoopssy',
#  'chimooopprrt',
#  'eeilmnorstuv',
#  'aeghhmoprrty',
#  'aceennorsssu',
#  'aceeilnoprss',
#  'aaciilnrsttu',
#  'aadeiilnnotu',
#  'abeiilnnostu',
#  'aehmnnooptty',
#  'ceeehlnoopps',
#  'aceghillnoop',
#  'eghilnooprst',
#  'acehhinopprt',
#  'adeehinopprs',
#  'aehinoopprst',
#  'ehinoopprssy',
#  'eehimnooprst',
#  'aceeiilnosst',
#  'aadeinnoprst',
#  'cdeefiinnort',
#  'acinnnorsttu',
#  'aceiilmnnopr',
#  'aaillmnnorty',
#  'aceiilnnoprt',
#  'aeefnnooprrt',
#  'ailnnnoopstu',
#  'ceeeinnorssv',
#  'aeginnnorstu',
#  'eeelnnosssst',
#  'abcinorssttu',
#  'acchiooprstt',
#  'aeghiilnoopr',
#  'ceghiilnoopr',
#  'aehinooprrtt',
#  'eghinooorstv',
#  'aacfiiilnopt',
#  'aabdeillmopt',
#  'aachimnoprrs',
#  'aaaacdiilprs',
#  'acilnooprstu',
#  'aceghloppryy',
#  'aeeinnoprstt',
#  'adeeenprrtuv',
#  'ceeeilpprtvy',
#  'aceellpprtuy',
#  'aceinnooprtt',
#  'ceeinoprrssu',
#  'aefiilnooprt',
#  'aeefimoprrtv',
#  'aceeiipprstt',
#  'aegilllnpruy',
#  'aeeilpprsttu',
#  'eeinoprsssuv',
#  'aeeghopprrrt',
#  'aceghiopprrt',
#  'ccehinoprsty',
#  'ehhiilooppss',
#  'beehilmoopst',
#  'aeghhoopprrt',
#  'acehlnooprst',
#  'dhlloooppsuy',
#  'eeghinopssty',
#  'ceeghinoptty',
#  'aaellnprstty',
#  'accilooprsuy',
#  'adhiioprrstt',
#  'aaceiloprstt',
#  'cdehilloopry',
#  'eeinooprssss',
#  'aacgiimprstt',
#  'aaghoopprssu',
#  'aceiiopprrtt',
#  'abceilnnopru',
#  'celnooprrstu',
#  'acdeiiloprst',
#  'deegiinoprst',
#  'cdeeiinprtuv',
#  'ceeegiinprrv',
#  'eeeilnprstvy',
#  'eeiilnprssst',
#  'abeinooprrst',
#  'einooopprrrt',
#  'cdeinooprrtu',
#  'aeinoopprrst',
#  'ainooprrsstt',
#  'ceeiooprrstt',
#  'chiooopprrtt',
#  'deelnoprstuy',
#  'cehhimopssty',
#  'aacceehinrst',
#  'aabeeelnrsst',
#  'aaeiilnorstz',
#  'aeemnorrsstt',
#  'aaceinorrttt',
#  'aacdeeglortu',
#  'cdeeehinrrst',
#  'aaceilmnorst',
#  'acceeilorstv',
#  'deeiinooprst',
#  'adeeiinorrtv',
#  'adeeeginrrtt',
#  'cdeeghilnrsu',
#  'aeeillrrsttu',
#  'eeiimnoprrss',
#  'cdeeinrrsttu',
#  'aeegimnnrrtu',
#  'aeeimnnorrtu',
#  'ceeeiprrssuv',
#  'abeehilnprsu',
#  'aeeghinrrstt',
#  'eeeghnnrrstt',
#  'aeiinnoprstu',
#  'aaelnnprrstt',
#  'eehloprrsstu',
#  'acefiiinortv',
#  'eeeilnrsssst',
#  'abcfiiinortu',
#  'aaccfiiorrst',
#  'aaaadilmnnrs',
#  'aaceilmsstty',
#  'eeimnoprsstu',
#  'aaegilnpsttu',
#  'eeinnoprsstu',
#  'aemnoooprstz',
#  'aceimooprstz',
#  'chimooprrstu',
#  'eelnopssssst',
#  'aeeflnsssttu',
#  'aeeimnorrstt',
#  'aceehmnrrstt',
#  'aehilooprstt',
#  'abcdeinrsssu',
#  'abeeilnssstu',
#  'aabeelnrrstu',
#  'abcdenrsttuu',
#  'aacelnprrsuu',
#  'eeinoprssssu',
#  'eeimnprrsstu',
#  'adhimnoprssw',
#  'aeflnoopsstu',
#  'abeehiinnrtt',
#  'aeegghinortt',
#  'aacchillorty',
#  'aaelmnnorttu',
#  'abceinrrrsst',
#  'aagillmnnruy',
#  'abcdeeelnrtu',
#  'aacdeglnotuu',
#  'ceginnnorsuv',
#  'ceginnnnottu',
#  'deghinnorrsu',
#  'adeegimnnnru',
#  'cddeenoprruu',
#  'abceeelnptux',
#  'aegimnnrtuuu',
#  'aeegimnnprtu',
#  'eeiimnprssuv',
#  'abdeeilmnruz',
#  'aaellnnprtuy',
#  'abeeelnnprtu',
#  'ceeeinpprtuv',
#  'adeeinnrsttu',
#  'aegiilnnorsu',
#  'beemnnorsssu',
#  'ceeinpsstuuv',
#  'aceilooprruv',
#  'aaiiilnosttv',
#  'aaabcehinrt',
#  'aabceinorst',
#  'aaacelprtty',
#  'aacceelorrt',
#  'accdeeinoss',
#  'acceeinorss',
#  'aaacdehinrt',
#  'acefiimnort',
#  'acdeeiinprs',
#  'aciimnoorsu',
#  'acciilmnoru',
#  'aacchilorst',
#  'acciimorsst',
#  'acilnooorst',
#  'acchiooprrt',
#  'aaacdeeinot',
#  'aceiinoprtt',
#  'aaciinosttv',
#  'aadiimnopst',
#  'accdeeinopt',
#  'aadeilmnoop',
#  'adiimnnoost',
#  'aabdiilorty',
#  'acdeilnorty',
#  'aadiinoprst',
#  'adeenrrstuv',
#  'acdefiimoor',
#  'aaeeghoprrr',
#  'aaceghioprr',
#  'aacegilloor',
#  'aaeimnorstu',
#  'aaceiorsstt',
#  'aacfilnnotu',
#  'aacgiilnost',
#  'abeeilmnruz',
#  'aaceegillns',
#  'accehiilmst',
#  'aaadeilnnrx',
#  'acghiilmort',
#  'aegillorsst',
#  'aaehillopst',
#  'adeiilnnost',
#  'aaeilnorstt',
#  'aadiillnttu',
#  'aabeiilmnty',
#  'aaeehlmnorr',
#  'adehilmnoop',
#  'acilmmnooty',
#  'aeeeemmprrt',
#  'aeghimnopsu',
#  'achhiilmopp',
#  'adhimooppsu',
#  'ahhimnoprtu',
#  'aacceinnort',
#  'aaemnooprty',
#  'aaaceillnpt',
#  'aaachilnopr',
#  'aaeelnoprss',
#  'aadhnooprrt',
#  'aaceilnorst',
#  ...]

# %%
# Wrap in list comprehension
[anagramsBySig[signature] for signature in sorted(anagramsBySig.keys(), key = len, reverse= True)]
# Out:
# [{'chlorotrifluoromethane', 'trifluorochloromethane'},
#  {'cholecystoduodenostomy', 'duodenocholecystostomy'},
#  {'hydropneumopericardium', 'pneumohydropericardium'},
#  {'anatomicopathological', 'pathologicoanatomical'},
#  {'chromophotolithograph', 'photochromolithograph'},
#  {'duodenopancreatectomy', 'pancreatoduodenectomy'},
#  {'glossolabiopharyngeal', 'labioglossopharyngeal'},
#  {'nitrotrichloromethane', 'trichloronitromethane'},
#  {'anatomicophysiologic', 'physiologicoanatomic'},
#  {'encephalomeningocele', 'meningoencephalocele'},
#  {'glossolabiolaryngeal', 'labioglossolaryngeal'},
#  {'anatomicopathologic', 'pathologicoanatomic'},
#  {'clinicopathological', 'pathologicoclinical'},
#  {'encephalomeningitis', 'meningoencephalitis'},
#  {'esophagogastrostomy', 'gastroesophagostomy'},
#  {'incontrovertibility', 'introconvertibility'},
#  {'pericardiacophrenic', 'phrenicopericardiac'},
#  {'physiopsychological', 'psychophysiological'},
#  {'bromochloromethane', 'chlorobromomethane'},
#  {'chondromyxosarcoma', 'myxochondrosarcoma'},
#  {'chorioidoretinitis', 'retinochorioiditis'},
#  {'chronophotographic', 'photochronographic'},
#  {'electrothermometer', 'thermoelectrometer'},
#  {'epididymovasostomy', 'vasoepididymostomy'},
#  {'galvanothermometer', 'thermogalvanometer'},
#  {'hexakistetrahedron', 'tetrakishexahedron'},
#  {'laryngopharyngitis', 'pharyngolaryngitis'},
#  {'laryngotracheotomy', 'tracheolaryngotomy'},
#  {'neuropsychological', 'psychoneurological'},
#  {'pathophysiological', 'physiopathological'},
#  {'pharmacopsychology', 'psychopharmacology'},
#  {'acetmethylanilide', 'methylacetanilide'},
#  {'basiparachromatin', 'marsipobranchiata'},
#  {'calcareosiliceous', 'siliceocalcareous'},
#  {'cephalomeningitis', 'meningocephalitis'},
#  {'cerebromeningitis', 'meningocerebritis'},
#  {'chemicomechanical', 'mechanicochemical'},
#  {'chemoprophyalctic', 'chemoprophylactic'},
#  {'chromolithography', 'lithochromography'},
#  {'chromophotography', 'photochromography'},
#  {'chronophotography', 'photochronography'},
#  {'constitutionalism', 'misconstitutional'},
#  {'dioeciopolygamous', 'polygamodioecious'},
#  {'electromagnetical', 'magnetoelectrical'},
#  {'encephalomyelitis', 'myeloencephalitis'},
#  {'hexakisoctahedron', 'octakishexahedron'},
#  {'hydropneumothorax', 'pneumohydrothorax'},
#  {'hysterolaparotomy', 'laparohysterotomy'},
#  {'hysteromyomectomy', 'myomohysterectomy'},
#  {'laryngopharyngeal', 'pharyngolaryngeal'},
#  {'lithonephrotomies', 'nephrolithotomies'},
#  {'microphotographer', 'photomicrographer'},
#  {'microphotographic', 'photomicrographic'},
#  {'microspectroscope', 'spectromicroscope'},
#  {'misrepresentation', 'representationism'},
#  {'nonconservational', 'nonconversational'},
#  {'pericardiopleural', 'pleuropericardial'},
#  {'antibenzaldoxime', 'benzantialdoxime'},
#  {'arthrochondritis', 'chondroarthritis'},
#  {'autoradiographic', 'radioautographic'},
#  {'biopsychological', 'psychobiological'},
#  {'calcareocorneous', 'corneocalcareous'},
#  {'carcinosarcomata', 'sarcocarcinomata'},
#  {'chronophotograph', 'photochronograph'},
#  {'configurationism', 'misconfiguration'},
#  {'dynamoelectrical', 'electrodynamical'},
#  {'ferrihydrocyanic', 'hydroferricyanic'},
#  {'ferrohydrocyanic', 'hydroferrocyanic'},
#  {'fibromyxosarcoma', 'myxofibrosarcoma'},
#  {'glycerophosphate', 'phosphoglycerate'},
#  {'heliophotography', 'photoheliography'},
#  {'hemopneumothorax', 'pneumohemothorax'},
#  {'incontrovertible', 'introconvertible'},
#  {'intestinovesical', 'vesicointestinal'},
#  {'laparosplenotomy', 'splenolaparotomy'},
#  {'lithophotography', 'photolithography'},
#  {'macrophotography', 'photomacrography'},
#  {'meningomyelocele', 'myelomeningocele'},
#  {'microphotographs', 'photomicrographs'},
#  {'microphotography', 'photomicrography'},
#  {'monopersulphuric', 'permonosulphuric'},
#  {'occipitotemporal', 'temporooccipital'},
#  {'parietosquamosal', 'squamosoparietal'},
#  {'pathophysiologic', 'physiopathologic'},
#  {'pectinatopinnate', 'pinnatopectinate'},
#  {'petrographically', 'pterylographical'},
#  {'pharyngorhinitis', 'rhinopharyngitis'},
#  {'photostereograph', 'stereophotograph'},
#  {'phototelegraphic', 'telephotographic'},
#  {'physiopsychology', 'psychophysiology'},
#  {'psychotechnology', 'technopsychology'},
#  {'pyeloureterogram', 'ureteropyelogram'},
#  {'sacculoutricular', 'utriculosaccular'},
#  {'somatosplanchnic', 'splanchnosomatic'},
#  {'spectrotelescope', 'telespectroscope'},
#  {'streptothricosis', 'streptotrichosis'},
#  {'abdominovaginal', 'vaginoabdominal'},
#  {'abdominovesical', 'vesicoabdominal'},
#  {'acoustoelectric', 'electroacoustic'},
#  {'algorithmically', 'logarithmically'},
#  {'aluminosilicate', 'silicoaluminate'},
#  {'antiproteolysis', 'proselytisation'},
#  {'autoradiography', 'radioautography'},
#  {'barothermograph', 'thermobarograph'},
#  {'biopsychologist', 'psychobiologist'},
#  {'biosociological', 'sociobiological'},
#  {'carcinosarcomas', 'sarcocarcinomas'},
#  {'chemicophysical', 'physicochemical'},
#  {'cinematographer', 'megachiropteran'},
#  {'columbotitanate', 'titanocolumbate'},
#  {'concessionaires', 'concessionaries'},
#  {'conservationism', 'conversationism'},
#  {'conservationist', 'conversationist'},
#  {'constructionism', 'misconstruction'},
#  {'cystourethritis', 'urethrocystitis'},
#  {'dactylopteridae', 'pterodactylidae'},
#  {'dermatoneurosis', 'neurodermatosis'},
#  {'dextrosinistral', 'sinistrodextral'},
#  {'ecclesiasticism', 'misecclesiastic'},
#  {'electromagnetic', 'magnetoelectric'},
#  {'encyclopaedical', 'encyclopediacal'},
#  {'enterogastritis', 'gastroenteritis'},
#  {'ethmosphenoidal', 'sphenoethmoidal'},
#  {'frontooccipital', 'occipitofrontal'},
#  {'gamogenetically', 'geomagnetically'},
#  {'germanification', 'remagnification'},
#  {'gramophonically', 'monographically', 'nomographically', 'phonogramically'},
#  {'hexatetrahedron', 'tetrahexahedron'},
#  {'imperscriptible', 'imprescriptible'},
#  {'impressibleness', 'permissibleness'},
#  {'inferoposterior', 'posteroinferior'},
#  {'interresponsive', 'nonperversities'},
#  {'involuntariness', 'nonuniversalist'},
#  {'lithonephrotomy', 'nephrolithotomy'},
#  {'macrophotograph', 'photomacrograph'},
#  {'meningomyelitis', 'myelomeningitis'},
#  {'microphotograph', 'photomicrograph'},
#  {'microphotoscope', 'photomicroscope'},
#  {'microradiometer', 'radiomicrometer'},
#  {'misunderstander', 'remisunderstand'},
#  {'noneffusiveness', 'unoffensiveness'},
#  {'parietotemporal', 'temporoparietal'},
#  {'parietovisceral', 'visceroparietal'},
#  {'pathophysiology', 'physiopathology'},
#  {'pathopsychology', 'psychopathology'},
#  {'phosphonuclease', 'sphenocephalous'},
#  {'phototelegraphy', 'telephotography'},
#  {'phototypography', 'phytotopography'},
#  {'pneumopyothorax', 'pyopneumothorax'},
#  {'posterosuperior', 'superoposterior'},
#  {'pretransmission', 'transimpression'},
#  {'pseudoeroticism', 'pseudoisometric'},
#  {'radiotelegraphy', 'teleradiography'},
#  {'reverifications', 'reversification'},
#  {'silicotungstate', 'tungstosilicate'},
#  {'stereotelescope', 'telestereoscope'},
#  {'sternovertebral', 'vertebrosternal'},
#  {'unavertibleness', 'unveritableness'},
#  {'uncreatableness', 'untraceableness'},
#  {'adenochondroma', 'chondroadenoma'},
#  {'adenosarcomata', 'sarcoadenomata'},
#  {'altitudinarian', 'latitudinarian'},
#  {'angiochondroma', 'chondroangioma'},
#  {'antarchistical', 'charlatanistic'},
#  {'anteroinferior', 'inferoanterior'},
#  {'anterosuperior', 'superoanterior'},
#  {'anticensorship', 'containerships'},
#  {'antinormalness', 'nonmartialness'},
#  {'associationism', 'misassociation'},
#  {'auriscopically', 'capsulociliary'},
#  {'autoradiograph', 'radioautograph'},
#  {'blastomycetous', 'cytoblastemous'},
#  {'borofluohydric', 'hydrofluoboric'},
#  {'carcinosarcoma', 'sarcocarcinoma'},
#  {'centralisation', 'intercalations'},
#  {'certifiability', 'rectifiability'},
#  {'certifications', 'rectifications'},
#  {'cervicovesical', 'vesicocervical'},
#  {'chloroplatinic', 'platinochloric'},
#  {'chondrofibroma', 'fibrochondroma'},
#  {'conservational', 'conversational'},
#  {'conservatoires', 'conservatories'},
#  {'consolidations', 'disconsolation'},
#  {'constitutioner', 'reconstitution'},
#  {'costovertebral', 'vertebrocostal'},
#  {'cystonephrosis', 'nephrocystosis'},
#  {'dentatoserrate', 'serratodentate'},
#  {'dentatosinuate', 'sinuatodentate'},
#  {'dipterological', 'pteridological'},
#  {'disintegration', 'disorientating'},
#  {'dorsoventrally', 'ventrodorsally'},
#  {'duodenojejunal', 'jejunoduodenal'},
#  {'dynamoelectric', 'electrodynamic'},
#  {'editorializers', 'radiosterilize'},
#  {'egocentrically', 'geocentrically'},
#  {'electrothermic', 'thermoelectric'},
#  {'encyclopaedist', 'encyclopediast'},
#  {'erythrophyllin', 'phylloerythrin'},
#  {'extirpationist', 'sextipartition'},
#  {'frontoparietal', 'parietofrontal'},
#  {'frontotemporal', 'temporofrontal'},
#  {'galvanopsychic', 'psychogalvanic'},
#  {'geissospermine', 'spermiogenesis'},
#  {'geohydrologist', 'hydrogeologist'},
#  {'headstrongness', 'strongheadness'},
#  {'hemiholohedral', 'holohemihedral'},
#  {'herpetological', 'pretheological'},
#  {'hydronephrosis', 'nephrohydrosis'},
#  {'hypergolically', 'hyperlogically'},
#  {'impressibility', 'permissibility'},
#  {'impressiveness', 'permissiveness'},
#  {'inconglomerate', 'nongeometrical'},
#  {'interpellation', 'interpollinate'},
#  {'interpermeated', 'predeterminate'},
#  {'intersectional', 'intraselection'},
#  {'interspiration', 'repristination'},
#  {'logometrically', 'metrologically'},
#  {'ludicroserious', 'serioludicrous'},
#  {'lusterlessness', 'resultlessness'},
#  {'medicophysical', 'physicomedical'},
#  {'metrophlebitis', 'phlebometritis'},
#  {'misrepresenter', 'remisrepresent'},
#  {'naturistically', 'unartistically'},
#  {'nephropyelitis', 'pyelonephritis'},
#  {'neuropsychosis', 'psychoneurosis'},
#  {'nondesecration', 'recondensation'},
#  {'paradisaically', 'paradisiacally'},
#  {'pectinesterase', 'prenecessitate'},
#  {'perineovaginal', 'vaginoperineal'},
#  {'perturbational', 'protuberantial'},
#  {'petrographical', 'pterographical'},
#  {'petrologically', 'pterylological'},
#  {'petrosquamosal', 'squamopetrosal'},
#  {'philanthropies', 'philanthropise'},
#  {'photoradiogram', 'radiophotogram'},
#  {'phototelegraph', 'telephotograph'},
#  {'pleurocentesis', 'superselection'},
#  {'pleurovisceral', 'visceropleural'},
#  {'preconsolation', 'spironolactone'},
#  {'prerealization', 'proletarianize'},
#  {'presentiveness', 'pretensiveness'},
#  {'prodeportation', 'proportionated'},
#  {'propitiousness', 'superpositions', 'superpossition'},
#  {'protomagnesium', 'spermatogonium'},
#  {'purpuroxanthin', 'xanthopurpurin'},
#  {'radiotelephone', 'teleradiophone'},
#  {'relativization', 'revitalization'},
#  {'rotundifoliate', 'titanofluoride'},
#  {'sacrovertebral', 'vertebrosacral'},
#  {'salinoterreous', 'soliterraneous'},
#  {'silicotitanate', 'titanosilicate'},
#  {'silicotungstic', 'tungstosilicic'},
#  {'tablespoonfuls', 'tablespoonsful'},
#  {'thunderbearing', 'underbreathing'},
#  {'transamination', 'transanimation'},
#  {'unamenableness', 'unnameableness'},
#  {'undefinability', 'unidentifiably'},
#  {'unperceptively', 'unpreceptively'},
#  {'accouterments', 'accoutrements'},
#  {'adenolymphoma', 'lymphoadenoma'},
#  {'adenosarcomas', 'sarcoadenomas'},
#  {'aeolharmonica', 'chloroanaemia'},
#  {'aerographical', 'areographical'},
#  {'amelification', 'maleficiation'},
#  {'amphitheatric', 'amphitrichate'},
#  {'amplification', 'palmification'},
#  {'angiocholitis', 'cholangioitis'},
#  {'angiokeratoma', 'keratoangioma'},
#  {'anticlinorium', 'inclinatorium'},
#  {'antiparticles', 'paternalistic'},
#  {'antiscorbutic', 'subcincttoria'},
#  {'antisoporific', 'prosification', 'sporification'},
#  {'argentiferous', 'garnetiferous'},
#  {'arthrosteitis', 'ostearthritis'},
#  {'atroceruleous', 'atrocoeruleus'},
#  {'attentiveness', 'tentativeness'},
#  {'autoheterosis', 'heteroousiast'},
#  {'beardlessness', 'breadlessness'},
#  {'benzofluorene', 'fluorobenzene'},
#  {'biopsychology', 'psychobiology'},
#  {'blastomycetic', 'cytoblastemic'},
#  {'botanophilist', 'philobotanist'},
#  {'brachiofacial', 'faciobrachial'},
#  {'buccocervical', 'cervicobuccal'},
#  {'cephalometric', 'petrochemical'},
#  {'cephalopodous', 'podocephalous'},
#  {'certification', 'cretification', 'rectification'},
#  {'certificative', 'rectificative'},
#  {'certificatory', 'rectificatory'},
#  {'cervicodorsal', 'dorsocervical'},
#  {'cervicofacial', 'faciocervical'},
#  {'cervicolabial', 'labiocervical'},
#  {'cheatableness', 'teachableness'},
#  {'cholesteremia', 'heteroecismal'},
#  {'chondrocostal', 'costochondral'},
#  {'chondrolipoma', 'lipochondroma'},
#  {'chondromyxoma', 'myxochondroma'},
#  {'circumcisions', 'circumcission'},
#  {'coloenteritis', 'enterocolitis'},
#  {'coloproctitis', 'proctocolitis'},
#  {'commercialist', 'microclimates'},
#  {'commissioners', 'recommissions'},
#  {'communalistic', 'communistical'},
#  {'competitioner', 'recompetition'},
#  {'compromission', 'procommission'},
#  {'condensations', 'consonantised'},
#  {'condylomatous', 'monodactylous'},
#  {'connectionism', 'misconnection'},
#  {'conservations', 'conversations'},
#  {'conservatoire', 'overreactions'},
#  {'considerative', 'devisceration'},
#  {'conterraneous', 'counterreason'},
#  {'contrarieties', 'recreationist'},
#  {'counterdemand', 'countermanded'},
#  {'countertrades', 'unstercorated'},
#  {'crimelessness', 'mercilessness'},
#  {'cruroinguinal', 'inguinocrural'},
#  {'cryptostomate', 'prostatectomy'},
#  {'cumulostratus', 'stratocumulus'},
#  {'cystopyelitis', 'pyelocystitis'},
#  {'dactylopterus', 'pterodactylus'},
#  {'deinocephalia', 'palaeechinoid'},
#  {'demandingness', 'maddeningness'},
#  {'demipronation', 'preadmonition', 'predomination'},
#  {'derationalize', 'derealization'},
#  {'derequisition', 'requisitioned'},
#  {'dermosclerite', 'sclerodermite'},
#  {'desulphurizer', 'resulphurized'},
#  {'diageotropism', 'geodiatropism'},
#  {'diplocephalus', 'pseudophallic'},
#  {'dipterologist', 'pteridologist'},
#  {'discriminator', 'doctrinairism'},
#  {'dislegitimate', 'legitimatised'},
#  {'distinguisher', 'redistinguish'},
#  {'documentaries', 'undemocratise'},
#  {'documentarily', 'unmaledictory'},
#  {'encaustically', 'unascetically'},
#  {'encyclopaedic', 'encyclopediac'},
#  {'endoarteritis', 'sideronatrite'},
#  {'epimyocardial', 'myoepicardial'},
#  {'ethmosphenoid', 'sphenoethmoid'},
#  {'ethologically', 'theologically'},
#  {'exploitations', 'sexploitation'},
#  {'expressionism', 'misexpression'},
#  {'frontoorbital', 'orbitofrontal'},
#  {'ganglioneuron', 'neuroganglion'},
#  {'gastrohepatic', 'hepatogastric'},
#  {'gastrophrenic', 'nephrogastric', 'phrenogastric'},
#  {'genitourinary', 'urinogenitary'},
#  {'geohydrologic', 'hydrogeologic'},
#  {'gesticulation', 'unegotistical'},
#  {'gonadotrophic', 'odontographic'},
#  {'gramophonical', 'monographical', 'nomographical'},
#  {'grandparental', 'grandpaternal'},
#  {'graphological', 'logographical'},
#  {'guarantorship', 'uranographist'},
#  {'hemicatalepsy', 'mesaticephaly'},
#  {'hepatomegalia', 'megalohepatia'},
#  {'hepatonephric', 'phrenohepatic'},
#  {'hydrosulphate', 'sulphohydrate'},
#  {'hypoglossitis', 'physiologists'},
#  {'iconometrical', 'intracoelomic'},
#  {'imperfections', 'perfectionism'},
#  {'impersonating', 'impregnations'},
#  {'impersonation', 'prosemination', 'semipronation'},
#  {'impressionism', 'misimpression'},
#  {'inconceivable', 'inconcievable'},
#  {'inconsonantly', 'nonsyntonical'},
#  {'incudomalleal', 'malleoincudal'},
#  {'innovationist', 'nonvisitation'},
#  {'inorthography', 'ornithography'},
#  {'insectologist', 'scientologist'},
#  {'instructional', 'nonaltruistic'},
#  {'interactional', 'intercalation'},
#  {'interceptions', 'septentrionic'},
#  {'intermorainic', 'recrimination'},
#  {'interspecific', 'prescientific'},
#  {'intervascular', 'vernacularist'},
#  {'introsensible', 'nonresistible'},
#  {'investigation', 'tenovaginitis'},
#  {'lachrymonasal', 'nasolachrymal'},
#  {'lateroventral', 'ventrolateral'},
#  {'marbelization', 'marbleization'},
#  {'matrilocality', 'triatomically'},
#  {'megalophonous', 'omphalogenous'},
#  {'megalosplenia', 'splenomegalia'},
#  {'micranthropos', 'promonarchist'},
#  {'micropetalous', 'somatopleuric'},
#  {'misperception', 'perceptionism'},
#  {'missuggestion', 'suggestionism'},
#  {'myeloneuritis', 'neuromyelitis'},
#  {'nephrectomies', 'nephrectomise'},
#  {'nephrocardiac', 'phrenocardiac'},
#  {'noneffusively', 'unoffensively'},
#  {'nonparentally', 'nonpaternally'},
#  {'ornithomantic', 'orthantimonic'},
#  {'orthographies', 'orthographise'},
#  {'osteometrical', 'stereotomical'},
#  {'overcirculate', 'uterocervical'},
#  {'oversauciness', 'veraciousness'},
#  {'paranephritis', 'paraphrenitis'},
#  {'paraproctitis', 'participators'},
#  {'parasyntheton', 'thysanopteran'},
#  {'patrilocality', 'patriotically'},
#  {'pedometrician', 'premedication'},
#  {'perambulation', 'preambulation'},
#  {'perambulatory', 'preambulatory'},
#  {'peridiastolic', 'periodicalist', 'pictorialised', 'proidealistic'},
#  {'personalistic', 'pictorialness'},
#  {'phonographist', 'phosphorating'},
#  {'phrenosplenic', 'splenonephric', 'splenophrenic'},
#  {'pneumatophony', 'pneumonopathy'},
#  {'podostomatous', 'stomatopodous'},
#  {'prediscretion', 'redescription'},
#  {'propraetorial', 'protoperlaria'},
#  {'protectorates', 'statoreceptor'},
#  {'protosulphide', 'sulphoproteid'},
#  {'pseudamoeboid', 'pseudoameboid'},
#  {'psychosomatic', 'somatopsychic'},
#  {'puritanically', 'unpiratically'},
#  {'pyosepticemia', 'septicopyemia'},
#  {'pyosepticemic', 'septicopyemic'},
#  {'recataloguing', 'recoagulating'},
#  {'redintegrator', 'retrogradient'},
#  {'reinstruction', 'unrestriction'},
#  {'reintegration', 'reorientating'},
#  {'restraightens', 'straighteners'},
#  {'restrengthens', 'strengtheners'},
#  {'resupposition', 'superposition'},
#  {'ritualization', 'uralitization'},
#  {'sacrification', 'scarification'},
#  {'scorbutically', 'subcortically'},
#  {'statelessness', 'tastelessness'},
#  {'superintended', 'unpredestined'},
#  {'superintender', 'unenterprised'},
#  {'unamenability', 'unnameability'},
#  {'uncertifiable', 'unrectifiable'},
#  {'unconservable', 'unconversable'},
#  {'unimpressible', 'unpermissible'},
#  {'unimpressibly', 'unpermissibly'},
#  {'unmarbelizing', 'unmarbleizing'},
#  {'unspecterlike', 'unspectrelike'},
#  {'unsusceptible', 'unsuspectible'},
#  {'vaginovesical', 'vesicovaginal'},
#  {'verifications', 'versification'},
#  {'abolitionism', 'mobilisation'},
#  {'acclimatiser', 'cameralistic'},
#  {'accomplisher', 'reaccomplish'},
#  {'accouterment', 'accoutrement'},
#  {'acherontical', 'anchoretical'},
#  {'achromatinic', 'chromatician'},
#  {'acidophilous', 'aphidicolous'},
#  {'acrostically', 'socratically'},
#  {'actinopteran', 'precantation'},
#  {'acutenaculum', 'unaccumulate'},
#  {'adenocystoma', 'cystoadenoma'},
#  {'adenofibroma', 'fibroadenoma'},
#  {'adenosarcoma', 'sarcoadenoma'},
#  {'adpromission', 'proadmission'},
#  {'adrenotropic', 'incorporated'},
#  {'adulterating', 'triangulated'},
#  {'alcantarines', 'lancasterian'},
#  {'allothogenic', 'ethnological'},
#  {'alterability', 'bilaterality', 'relatability'},
#  {'altercations', 'intercoastal'},
#  {'altitudinous', 'latitudinous'},
#  {'ameliorating', 'emigrational'},
#  {'amenorrhoeal', 'melanorrhoea'},
#  {'amphitheater', 'amphitheatre'},
#  {'amphitropous', 'pastophorium'},
#  {'anecdotalism', 'declamations'},
#  {'anemographic', 'phanerogamic'},
#  {'angiofibroma', 'fibroangioma'},
#  {'anitrogenous', 'outreasoning'},
#  {'annomination', 'nonanimation'},
#  {'anteluminary', 'unalimentary'},
#  {'antepreterit', 'interpretate'},
#  {'anticreation', 'antireaction'},
#  {'anticreative', 'antireactive'},
#  {'anticrotalic', 'calcitration'},
#  {'antifriction', 'nitrifaction'},
#  {'antimosquito', 'misquotation'},
#  {'antinegroism', 'germinations'},
#  {'antineutrons', 'unstentorian'},
#  {'antiparticle', 'antiprelatic'},
#  {'antiphonetic', 'pentathionic'},
#  {'antiprotease', 'entoparasite'},
#  {'antiroyalist', 'stationarily'},
#  {'antitropical', 'practitional'},
#  {'aphorismical', 'parochialism'},
#  {'aphoristical', 'parochialist'},
#  {'apothecaries', 'spirochaetae'},
#  {'aqueoigneous', 'igneoaqueous'},
#  {'archoverseer', 'overreachers'},
#  {'aristotelian', 'retaliations'},
#  {'arsenicating', 'ascertaining'},
#  {'arsenopyrite', 'pyroarsenite'},
#  {'artillerymen', 'termillenary'},
#  {'basidiophore', 'siderophobia'},
#  {'behaviourism', 'misbehaviour'},
#  {'bicarpellary', 'irreplacably', 'prebacillary'},
#  {'biosociology', 'sociobiology'},
#  {'bitonalities', 'notabilities'},
#  {'blastocoelic', 'coeloblastic'},
#  {'blepharocera', 'reproachable'},
#  {'branchiopoda', 'podobranchia'},
#  {'breakweather', 'weatherbreak'},
#  {'broadcasters', 'rebroadcasts'},
#  {'bromohydrate', 'hydrobromate'},
#  {'cacodaemonic', 'cacodemoniac'},
#  {'callisection', 'clinoclasite'},
#  {'calotermitid', 'dilatometric'},
#  {'canalisation', 'nacionalista'},
#  {'capsulectomy', 'scapulectomy'},
#  {'carbohydride', 'hydrocarbide'},
#  {'cartesianism', 'sectarianism'},
#  {'catholiciser', 'ischiorectal', 'sciotherical'},
#  {'caudofemoral', 'femorocaudal'},
#  {'caudolateral', 'laterocaudal'},
#  {'cautionaries', 'cetiosaurian'},
#  {'centrodorsal', 'doroscentral', 'dorsocentral'},
#  {'centrolineal', 'crenellation'},
#  {'ceratothecal', 'chloracetate'},
#  {'certificator', 'rectificator'},
#  {'cervicodynia', 'corycavidine'},
#  {'cetorhinidae', 'dichotriaene'},
#  {'chapelmaster', 'spermathecal'},
#  {'chaperonless', 'proseneschal'},
#  {'characteries', 'characterise'},
#  {'cheiropodist', 'coeditorship'},
#  {'chemicovital', 'vitochemical'},
#  {'chemotropism', 'ectomorphism'},
#  {'chiromancist', 'monarchistic'},
#  {'chirosophist', 'opisthorchis'},
#  {'chlorioninae', 'rhinocoelian'},
#  {'chloroanemia', 'choleromania'},
#  {'chloroiodide', 'iodochloride'},
#  {'chromatocyte', 'thoracectomy'},
#  {'chromolithic', 'lithochromic'},
#  {'chronomantic', 'nonchromatic'},
#  {'chrysography', 'psychorrhagy'},
#  {'cirrocumulus', 'cumulocirrus'},
#  {'clarinetists', 'triticalness'},
#  {'clonicotonic', 'tonicoclonic'},
#  {'coalitionist', 'solicitation'},
#  {'coincidental', 'nondialectic'},
#  {'collectioner', 'recollection'},
#  {'colonialists', 'oscillations'},
#  {'colpeurynter', 'counterreply'},
#  {'colporrhagia', 'orographical'},
#  {'commentarial', 'manometrical'},
#  {'commissariat', 'marcatissimo'},
#  {'commissioned', 'decommission'},
#  {'commissioner', 'recommission'},
#  {'commonership', 'morphonemics'},
#  {'communaliser', 'semicolumnar'},
#  {'compenetrate', 'contemperate'},
#  {'comprehender', 'recomprehend'},
#  {'concentering', 'reconnecting'},
#  {'concentrates', 'concertantes'},
#  {'concertizing', 'concretizing'},
#  {'concessioner', 'reconcession'},
#  {'conditioners', 'reconditions'},
#  {'connoissance', 'nonaccession'},
#  {'consarcinate', 'narcaciontes', 'transoceanic'},
#  {'conservation', 'conversation'},
#  {'conservative', 'conversative'},
#  {'consimilated', 'maledictions'},
#  {'consolidates', 'disconsolate'},
#  {'constrainers', 'contrariness'},
#  {'containments', 'sanctionment'},
#  {'conturbation', 'obtruncation'},
#  {'conventioner', 'reconvention'},
#  {'coprolagnist', 'prognostical'},
#  {'coprophagist', 'topographics'},
#  {'corelational', 'reallocation'},
#  {'cornucopiate', 'reoccupation'},
#  {'corporealist', 'prosectorial'},
#  {'correctioner', 'recorrection'},
#  {'costosternal', 'sternocostal'},
#  {'counteracter', 'countercarte'},
#  {'countercharm', 'countermarch'},
#  {'counterguard', 'uncorrugated'},
#  {'counterideal', 'reinoculated'},
#  {'counterpaled', 'counterplead', 'unpercolated'},
#  {'counterpoint', 'unprotection'},
#  {'counterpoles', 'counterslope'},
#  {'countershade', 'decantherous'},
#  {'counterspies', 'persecutions'},
#  {'counterstain', 'encrustation'},
#  {'counterstand', 'uncontrasted'},
#  {'courtiership', 'peritrichous'},
#  {'creativeness', 'reactiveness'},
#  {'creditorship', 'directorship'},
#  {'cremationism', 'semiromantic'},
#  {'crestmoreite', 'stereometric'},
#  {'cricothyroid', 'thyrocricoid'},
#  {'crurogenital', 'genitocrural'},
#  {'curvidentate', 'undetractive'},
#  {'customhouses', 'customshouse'},
#  {'cystofibroma', 'fibrocystoma'},
#  {'decimestrial', 'sedimetrical'},
#  {'declinations', 'nondeistical', 'nonsilicated'},
#  {'definability', 'identifiably'},
#  {'deinsularize', 'unserialized'},
#  {'delicateness', 'delicatessen'},
#  {'delimitation', 'mniotiltidae'},
#  {'demagnetiser', 'disagreement'},
#  {'demagnetizer', 'remagnetized'},
#  {'demiparallel', 'imparalleled'},
#  {'democratised', 'semicordated'},
#  {'demonstrater', 'remonstrated'},
#  {'denizenation', 'endenization'},
#  {'denomination', 'nonmediation'},
#  {'denominative', 'nonmediative'},
#  {'denotational', 'detonational'},
#  {'dentilingual', 'indulgential', 'linguidental'},
#  {'dentolingual', 'linguodental'},
#  {'depilatories', 'peridiastole'},
#  {'depositional', 'despoliation'},
#  {'depreciation', 'predeication'},
#  {'deprogrammer', 'reprogrammed'},
#  {'derelinquish', 'relinquished'},
#  {'derivational', 'revalidation'},
#  {'dermatitises', 'disastimeter', 'semistriated'},
#  {'dermatophone', 'herpetomonad'},
#  {'desensitizer', 'resensitized'},
#  {'despairingly', 'redisplaying'},
#  {'destinations', 'dissentation'},
#  {'desulfurizer', 'resulfurized'},
#  {'detruncating', 'undetracting'},
#  {'deuteranopic', 'preeducation'},
#  {'diplostemony', 'polydemonist'},
#  {'dipteraceous', 'epiceratodus'},
#  {'disadventure', 'unadvertised'},
#  {'discontinual', 'nondualistic'},
#  {'discontinuer', 'undiscretion'},
#  {'discreetness', 'discreteness'},
#  {'discrepation', 'predications'},
#  {'disculpation', 'duplications'},
#  {'disharmonies', 'disharmonise'},
#  {'distemperate', 'preestimated', 'premeditates'},
#  {'domification', 'modification'},
#  {'dorsolateral', 'laterodorsal'},
#  {'dorsoventrad', 'ventrodorsad'},
#  {'dorsoventral', 'ventrodorsal'},
#  {'elementarity', 'intemerately'},
#  {'empathically', 'emphatically'},
#  {'encastrement', 'reenactments'},
#  {'encounterers', 'reencounters'},
#  {'energeticist', 'energetistic'},
#  {'enlighteners', 'reenlightens'},
#  {'enormousness', 'unmoroseness'},
#  {'enterprising', 'preinserting'},
#  {'entertaining', 'intenerating'},
#  {'enthusiastic', 'unchastities'},
#  {'entomologies', 'entomologise'},
#  {'enumerations', 'mountaineers'},
#  {'episternalia', 'plaisanterie'},
#  {'epitrachelia', 'perichaetial'},
#  {'erythrophage', 'heterography'},
#  {'etherization', 'heterization'},
#  {'ethnocentric', 'technetronic'},
#  {'exacervation', 'reexcavation'},
#  {'exasperation', 'xenoparasite'},
#  {'excoriations', 'exorcisation'},
#  {'exhibitioner', 'reexhibition'},
#  {'experimenter', 'reexperiment'},
#  {'expositional', 'exspoliation'},
#  {'extraliminal', 'intermaxilla'},
#  {'famelessness', 'selfsameness'},
#  {'femorotibial', 'tibiofemoral'},
#  {'fibroneuroma', 'neurofibroma'},
#  {'fingerflower', 'fringeflower'},
#  {'foundationer', 'refoundation'},
#  {'gallotannate', 'tannogallate'},
#  {'gastropathic', 'graphostatic'},
#  {'geohydrology', 'hydrogeology'},
#  {'glossolabial', 'labioglossal'},
#  {'gonidiferous', 'indigoferous'},
#  {'gramophonist', 'monographist'},
#  {'graphophonic', 'phonographic'},
#  {'hairbreadths', 'hairsbreadth'},
#  {'haplobiontic', 'philobotanic'},
#  {'haptophorous', 'pathophorous'},
#  {'hemiteratics', 'semitheatric'},
#  {'heretication', 'theoretician'},
#  {'heterocarpus', 'urethrascope'},
#  {'heterogynous', 'thyreogenous'},
#  {'homeotypical', 'polymetochia'},
#  {'humeroradial', 'radiohumeral'},
#  {'humoralistic', 'humoristical'},
#  {'hurtlessness', 'ruthlessness'},
#  {'hydrosulfate', 'sulfohydrate'},
#  {'hypostomatic', 'somatophytic'},
#  {'hypothecater', 'tracheophyte'},
#  {'hysteropathy', 'hysterophyta'},
#  {'iatraliptics', 'partialistic'},
#  {'idiomorphous', 'oophoridiums'},
#  {'impenetrable', 'intemperable'},
#  {'impenetrably', 'intemperably'},
#  {'impersonated', 'predominates'},
#  {'importunance', 'unimportance'},
#  {'imprecisions', 'precisionism'},
#  {'impressively', 'permissively'},
#  {'inactivating', 'vaticinating'},
#  {'inactivation', 'vaticination'},
#  {'inadulterate', 'unretaliated'},
#  {'incomputable', 'uncompatible'},
#  {'incomputably', 'uncompatibly'},
#  {'inconsistent', 'nonscientist'},
#  {'indefinitude', 'unidentified'},
#  {'indeprivable', 'predivinable'},
#  {'indirections', 'indiscretion'},
#  {'indiscreetly', 'indiscretely', 'iridescently'},
#  {'inobtainable', 'nonbilabiate'},
#  {'inoculations', 'inosculation'},
#  {'inoperculata', 'precautional'},
#  {'inseminators', 'nestorianism'},
#  {'inspectorate', 'stereoptican'},
#  {'inspectorial', 'replications'},
#  {'intercession', 'recensionist'},
#  {'intercoupled', 'pleuronectid'},
#  {'intercreedal', 'recredential'},
#  {'interimistic', 'trimesitinic'},
#  {'intermontane', 'reanointment'},
#  {'interoceptor', 'reprotection'},
#  {'interpellate', 'pantellerite'},
#  {'interpolates', 'steprelation'},
#  {'interpreters', 'reinterprets'},
#  {'interproduce', 'prereduction'},
#  {'intersituate', 'tenuistriate'},
#  {'interstation', 'strontianite'},
#  {'intervention', 'introvenient'},
#  {'intolerating', 'nitrogelatin'},
#  {'involutional', 'unvolitional'},
#  {'iridectomies', 'iridectomise', 'mediocrities'},
#  {'irrationable', 'orbitelarian'},
#  {'irrepentance', 'pretercanine'},
#  {'irreversible', 'liverberries'},
#  {'isosaccharic', 'sacroischiac'},
#  {'itemizations', 'semitization'},
#  {'kinaesthesis', 'kinesthesias'},
#  {'lactoprotein', 'protectional'},
#  {'lateenrigged', 'redelegating'},
#  {'lepidosauria', 'pliosauridae'},
#  {'lipsanotheca', 'sphacelation'},
#  {'lithonephria', 'philotherian'},
#  {'logometrical', 'metrological'},
#  {'longitudianl', 'longitudinal'},
#  {'lymphectasia', 'metaphysical'},
#  {'malacologist', 'mastological'},
#  {'maneuverable', 'manueverable'},
#  {'manoeuvering', 'manoeuvreing'},
#  {'manslaughter', 'slaughterman'},
#  {'mantelpieces', 'mantlepieces'},
#  {'mastigophore', 'tomographies'},
#  {'matelessness', 'tamelessness'},
#  {'matriclinous', 'unmoralistic'},
#  {'matriculated', 'trimaculated'},
#  {'medioventral', 'ventromedial'},
#  {'merchandiser', 'merchandrise'},
#  {'metaphorical', 'pharmacolite'},
#  {'metronomical', 'monometrical'},
#  {'metropolises', 'pleometrosis'},
#  {'microcephaly', 'pyrochemical'},
#  {'micropterous', 'prosectorium'},
#  {'microsiemens', 'necromimesis'},
#  {'misreporting', 'spiritmonger'},
#  {'mistradition', 'traditionism'},
#  {'monocystidae', 'monocystidea'},
#  {'monophyllous', 'nomophyllous'},
#  {'monopsychism', 'psychomonism'},
#  {'morphotropic', 'protomorphic'},
#  {'multinervose', 'volunteerism'},
#  {'mythographer', 'thermography'},
#  {'nacreousness', 'uncoarseness'},
#  {'narcolepsies', 'precessional'},
#  {'naturalistic', 'unartistical'},
#  {'nautiloidean', 'unideational'},
#  {'nebulisation', 'sublineation'},
#  {'nematophyton', 'tenontophyma'},
#  {'nepheloscope', 'phonelescope'},
#  {'nephological', 'phenological'},
#  {'nephrologist', 'phrenologist'},
#  {'nephropathic', 'phrenopathic'},
#  {'nephropsidae', 'praesphenoid'},
#  {'nephroptosia', 'prosiphonate'},
#  {'nephropyosis', 'pyonephrosis'},
#  {'nephrotomies', 'nephrotomise'},
#  {'nesosilicate', 'sectionalise'},
#  {'nonaspirated', 'nondisparate'},
#  {'noncertified', 'nonrectified'},
#  {'noncurantist', 'unconstraint'},
#  {'nonempirical', 'prenominical'},
#  {'nonmaritally', 'nonmartially'},
#  {'nonpearlitic', 'pratincoline'},
#  {'nonperforate', 'preafternoon'},
#  {'nonplusation', 'nonpulsation'},
#  {'nonrecessive', 'overniceness'},
#  {'nonsignature', 'unresonating'},
#  {'notelessness', 'tonelessness'},
#  {'obscurantist', 'substraction', 'subtractions'},
#  {'octastrophic', 'postthoracic'},
#  {'oligonephria', 'oligophrenia'},
#  {'oligonephric', 'oligophrenic'},
#  {'ornithoptera', 'prototherian'},
#  {'overshooting', 'oversoothing'},
#  {'palification', 'pontificalia'},
#  {'palmatilobed', 'palmilobated'},
#  {'parachronism', 'proanarchism'},
#  {'paradisaical', 'paradisiacal'},
#  {'patroclinous', 'pratincolous'},
#  {'pelycography', 'pyrgocephaly'},
#  {'penetrations', 'presentation'},
#  {'peradventure', 'preadventure'},
#  {'perceptively', 'preceptively'},
#  {'perceptually', 'preceptually'},
#  {'percontation', 'pernoctation'},
#  {'percussioner', 'repercussion'},
#  {'perfoliation', 'prefoliation'},
#  {'performative', 'preformative'},
#  {'peripatetics', 'precipitates'},
#  {'perlingually', 'prelingually'},
#  {'perpetualist', 'pluriseptate'},
#  {'perviousness', 'previousness', 'viperousness'},
#  {'petrographer', 'pterographer'},
#  {'petrographic', 'pterographic'},
#  {'phenocrystic', 'pyrotechnics'},
#  {'philosophies', 'philosophise'},
#  {'phlebotomies', 'phlebotomise'},
#  {'photographer', 'rephotograph'},
#  {'phrenocostal', 'plastochrone'},
#  {'phyllopodous', 'podophyllous'},
#  {'phytogenesis', 'pythogenesis'},
#  {'phytogenetic', 'pythogenetic'},
#  {'platysternal', 'transeptally'},
#  {'plousiocracy', 'procaciously'},
#  {'podarthritis', 'traditorship'},
#  {'poetastrical', 'spectatorial'},
#  {'policyholder', 'polychloride'},
#  {'possessioner', 'repossession'},
#  {'pragmaticist', 'pragmatistic'},
#  {'prasophagous', 'saprophagous'},
#  {'precipitator', 'prepatriotic'},
#  {'preconnubial', 'pronunciable'},
#  {'preconsultor', 'supercontrol'},
#  {'prediastolic', 'psiloceratid', 'tropicalised'},
#  {'predigestion', 'redepositing'},
#  {'preinductive', 'unpredictive'},
#  {'prereceiving', 'reperceiving'},
#  {'presentively', 'pretensively'},
#  {'priestliness', 'spriteliness'},
#  {'probationers', 'reabsorption'},
#  {'proportioner', 'reproportion'},
#  {'proreduction', 'reproduction'},
#  {'prosperation', 'reapportions'},
#  {'prostrations', 'transpositor'},
#  {'protectories', 'stereotropic'},
#  {'prototrophic', 'trophotropic'},
#  {'pseudelytron', 'unproselyted'},
#  {'psychotheism', 'theopsychism'},
#  {'rachianectes', 'rhacianectes'},
#  {'rateableness', 'tearableness'},
#  {'rationalizes', 'realizations'},
#  {'reassortment', 'remonstrates'},
#  {'reattraction', 'retractation'},
#  {'recatalogued', 'recoagulated'},
#  {'rechristened', 'trencherside'},
#  {'reclamations', 'romancealist'},
#  {'rectovesical', 'vesicorectal'},
#  {'redeposition', 'repositioned'},
#  {'rederivation', 'veratroidine'},
#  {'redintegrate', 'reintegrated'},
#  {'reichsgulden', 'rescheduling'},
#  {'reillustrate', 'ultrasterile'},
#  {'reimpression', 'repermission'},
#  {'reinstructed', 'unrestricted'},
#  {'remunerating', 'renumerating'},
#  {'remuneration', 'renumeration'},
#  {'repercussive', 'superservice'},
#  {'repunishable', 'unperishable'},
#  {'restraighten', 'straightener'},
#  {'restrengthen', 'strengthener'},
#  {'resupination', 'uranospinite'},
#  {'retransplant', 'transplanter'},
#  {'reupholsters', 'upholsterers'},
#  {'revification', 'verification'},
#  {'ritelessness', 'tirelessness'},
#  {'rubification', 'urbification'},
#  {'sacrificator', 'scarificator'},
#  {'salamandarin', 'salamandrian', 'salamandrina'},
#  {'semicatalyst', 'systematical'},
#  {'sempiternous', 'supermoisten'},
#  {'septaugintal', 'septuagintal'},
#  {'serpentinous', 'supertension'},
#  {'speramtozoon', 'spermatozoon'},
#  {'spermatozoic', 'zoospermatic'},
#  {'sporotrichum', 'trichosporum'},
#  {'spotlessness', 'stoplessness'},
#  {'statefulness', 'tastefulness'},
#  {'strainometer', 'ternstroemia'},
#  {'stretcherman', 'trenchmaster'},
#  {'strophiolate', 'theatropolis'},
#  {'subacridness', 'subradicness'},
#  {'subessential', 'suitableness'},
#  {'subterraneal', 'unarrestable'},
#  {'subtruncated', 'unsubtracted'},
#  {'supernacular', 'supranuclear'},
#  {'supersession', 'suspensories'},
#  {'surprisement', 'trumperiness'},
#  {'swordmanship', 'wordsmanship'},
#  {'teaspoonfuls', 'teaspoonsful'},
#  {'terebinthian', 'terebinthina'},
#  {'theatergoing', 'theatregoing'},
#  {'thoracically', 'trochaically'},
#  {'tournamental', 'ultramontane'},
#  {'transcribers', 'transscriber'},
#  {'unalarmingly', 'unmarginally'},
#  {'unbraceleted', 'uncelebrated'},
#  {'uncatalogued', 'uncoagulated'},
#  {'unconserving', 'unconversing'},
#  {'uncontenting', 'uncontingent'},
#  {'underhorsing', 'undershoring'},
#  {'undermeaning', 'unmeandering'},
#  {'underproduce', 'unreproduced'},
#  {'unexceptable', 'unexpectable'},
#  {'ungeuntarium', 'unguentarium'},
#  {'unimpregnate', 'unpermeating'},
#  {'unimpressive', 'unpermissive'},
#  {'unmarbelized', 'unmarbleized'},
#  {'unparentally', 'unpaternally'},
#  {'unpenetrable', 'unrepentable'},
#  {'unperceptive', 'unpreceptive'},
#  {'unreinstated', 'unstraitened'},
#  {'unseignioral', 'unseignorial'},
#  {'unsomberness', 'unsombreness'},
#  {'unsusceptive', 'unsuspective'},
#  {'variocoupler', 'variocuopler'},
#  {'visitational', 'vitalisation'},
#  {'abranchiate', 'antebrachia'},
#  {'abreactions', 'craniotabes'},
#  {'acalyptrate', 'calyptratae'},
#  {'accelerator', 'retrocaecal'},
#  {'accessioned', 'deaccession'},
#  {'accessioner', 'reaccession'},
#  {'acidanthera', 'cantharidae'},
#  {'acinetiform', 'rifacimento'},
#  {'acipenserid', 'presidencia'},
#  {'acrimonious', 'isocoumarin'},
#  {'acroclinium', 'alcicornium'},
#  {'acrostichal', 'charcoalist'},
#  {'acrosticism', 'socraticism'},
#  {'acrostolion', 'colorations'},
#  {'acrotrophic', 'prothoracic'},
#  {'actaeonidae', 'donatiaceae'},
#  {'actinopteri', 'crepitation', 'precitation'},
#  {'activations', 'cavitations', 'vacationist'},
#  {'adaptionism', 'adoptianism'},
#  {'adenectopic', 'pentadecoic'},
#  {'adenolipoma', 'palaemonoid'},
#  {'admonitions', 'dominations'},
#  {'adorability', 'roadability'},
#  {'adrenolytic', 'declinatory'},
#  {'adspiration', 'disparation', 'tridiapason'},
#  {'adventurers', 'untraversed'},
#  {'aecidioform', 'formicoidea'},
#  {'aerographer', 'areographer'},
#  {'aerographic', 'areographic'},
#  {'aerological', 'areological'},
#  {'aeronautism', 'measuration'},
#  {'aerostatics', 'aortectasis'},
#  {'afunctional', 'unfactional'},
#  {'agonistical', 'analogistic'},
#  {'albumenizer', 'unmarbelize', 'unmarbleize'},
#  {'alcaligenes', 'allegiances'},
#  {'alchemistic', 'hemiclastic'},
#  {'alexandrian', 'alexandrina'},
#  {'algorithmic', 'logarithmic'},
#  {'allegorists', 'legislators'},
#  {'allopathies', 'lalopathies'},
#  {'alstonidine', 'nonidealist'},
#  {'alterations', 'intraosteal'},
#  {'altitudinal', 'latitudinal'},
#  {'amenability', 'nameability'},
#  {'amenorrheal', 'melanorrhea'},
#  {'amidophenol', 'monodelphia'},
#  {'ammonolytic', 'commonality'},
#  {'amperemeter', 'permeameter'},
#  {'amphigenous', 'musophagine'},
#  {'amphiphloic', 'amphophilic'},
#  {'amphipodous', 'hippodamous'},
#  {'amphithuron', 'phoranthium'},
#  {'anacreontic', 'canceration'},
#  {'anaemotropy', 'paramyotone'},
#  {'analeptical', 'placentalia'},
#  {'anaphorical', 'pharaonical'},
#  {'anapleroses', 'preseasonal'},
#  {'anarthropod', 'arthropodan'},
#  {'ancestorial', 'lacerations'},
#  ...]

# %%
help(pd.api)
# Out:
# Help on package pandas.api in pandas:
#
# NAME
#     pandas.api - public toolkit API
#
# PACKAGE CONTENTS
#     extensions (package)
#     indexers (package)
#     types (package)
#
# FILE
#     /Users/aepperly/opt/anaconda3/lib/python3.9/site-packages/pandas/api/__init__.py

# %%
pd.__version__
# Out:
# '1.4.2'
