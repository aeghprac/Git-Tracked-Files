# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
oo = pd.read_csv('olympics.csv', header = 4)

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo[['City', 'Edition', 'Sport']]
# Out:
#           City  Edition      Sport
# 0       Athens     1896   Aquatics
# 1       Athens     1896   Aquatics
# 2       Athens     1896   Aquatics
# 3       Athens     1896   Aquatics
# 4       Athens     1896   Aquatics
# ...        ...      ...        ...
# 29211  Beijing     2008  Wrestling
# 29212  Beijing     2008  Wrestling
# 29213  Beijing     2008  Wrestling
# 29214  Beijing     2008  Wrestling
# 29215  Beijing     2008  Wrestling
#
# [29216 rows x 3 columns]

# %%
pd.read_sql_table?
# Out:
# Signature:
# pd.read_sql_table(
#     table_name: 'str',
#     con,
#     schema: 'str | None' = None,
#     index_col: 'str | Sequence[str] | None' = None,
#     coerce_float: 'bool' = True,
#     parse_dates=None,
#     columns=None,
#     chunksize: 'int | None' = None,
# ) -> 'DataFrame | Iterator[DataFrame]'
# Docstring:
# Read SQL database table into a DataFrame.
#
# Given a table name and a SQLAlchemy connectable, returns a DataFrame.
# This function does not support DBAPI connections.
#
# Parameters
# ----------
# table_name : str
#     Name of SQL table in database.
# con : SQLAlchemy connectable or str
#     A database URI could be provided as str.
#     SQLite DBAPI connection mode not supported.
# schema : str, default None
#     Name of SQL schema in database to query (if database flavor
#     supports this). Uses default schema if None (default).
# index_col : str or list of str, optional, default: None
#     Column(s) to set as index(MultiIndex).
# ...

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
#oo.Edition.value_counts()
pd.value_counts(oo.Edition)
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.sort_values(by = ['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
oo.Medal == 'Gold'# just gives boolean index
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
oo[oo.Medal == 'Gold'] # gives a data frame based on boolean index
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')] # if using two must use parentheses and & symbol
# | for or, ~ for not
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
oo.Athlete.str.contains('Florence') #just prints out boolean series
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Athlete, Length: 29216, dtype: bool

# %%
oo[oo.Athlete.str.contains('Florence')] # use as index
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
#In which events did jesse owens win a medal?
oo[oo.Athlete.str.contains('owens', case=False)]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
### What country has won most badminton medals?
# Make oo for badminton
bad = oo[oo.Sport.str.contains('badminton', case=False)]

# %%
# check oo and sort by players' names
bad.sort_values(by = 'Athlete')
# Out:
#             City  Edition      Sport Discipline         Athlete  NOC Gender  \
# 23700     Sydney     2000  Badminton  Badminton   ARCHER, Simon  GBR    Men
# 25738     Athens     2004  Badminton  Badminton     AUDINA, Mia  NED  Women
# 21791    Atlanta     1996  Badminton  Badminton     AUDINA, Mia  INA  Women
# 20050  Barcelona     1992  Badminton  Badminton  BANG, Soo-Hyun  KOR  Women
# 21790    Atlanta     1996  Badminton  Badminton  BANG, Soo-Hyun  KOR  Women
# ...          ...      ...        ...        ...             ...  ...    ...
# 23703     Sydney     2000  Badminton  Badminton      ZHANG, Jun  CHN    Men
# 25737     Athens     2004  Badminton  Badminton     ZHANG, Ning  CHN  Women
# 27744    Beijing     2008  Badminton  Badminton     ZHANG, Ning  CHN  Women
# 27732    Beijing     2008  Badminton  Badminton    ZHANG, Yawen  CHN  Women
# 25736     Athens     2004  Badminton  Badminton        ZHOU, Mi  CHN  Women
#
#          Event Event_gender   Medal
# ...

# %%
# Check value counts
bad.NOC.value_counts()
# Out:
# CHN    47
# KOR    31
# INA    26
# MAS     6
# DEN     5
# GBR     4
# NED     1
# Name: NOC, dtype: int64

# %%
### Which three countries have won most medals from 1984-2008?
# Make oo for recent years
recent = oo[oo.Edition >= 1984]

# %%
# top 3 countries
recent.NOC.value_counts().head(3).plot(kind='bar',colormap= 'Pastel1')
# Out:
# <AxesSubplot:>

# %%
m100g = oo[(oo.Gender == 'Men') 
                & (oo.Sport.str.contains('Athletics', case = False))
                & (oo.Event == '100m')
                & (oo.Medal == 'Gold')]
m100g.sort_values('Athlete')
#& (oo.Medal == 'Gold') & (oo.Sport.str.contains('100m'))]
# Out:
#                         City  Edition      Sport Discipline  \
# 4236                   Paris     1924  Athletics  Athletics
# 21598                Atlanta     1996  Athletics  Athletics
# 27552                Beijing     2008  Athletics  Athletics
# 12902                 Munich     1972  Athletics  Athletics
# 13                    Athens     1896  Athletics  Athletics
# 19859              Barcelona     1992  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 14069               Montreal     1976  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 25539                 Athens     2004  Athletics  Athletics
# 23521                 Sydney     2000  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# 11865                 Mexico     1968  Athletics  Athletics
# ...

# %%
m100g.sort_values('Edition', ascending=False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %% [markdown]
# # Plots n shit

# %%
# top 3 countries
recent.NOC.value_counts().head(3).plot(kind='bar',colormap= 'Pastel1'); #semicolon deletes stupid line at top

# %%
recent.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
top = pd.DataFrame(recent.NOC.value_counts().head(3))

# %%
top
# Out:
#       NOC
# USA  1837
# AUS   762
# GER   691

# %%
top.reset_index(inplace=True) # add new index
top = top.rename(columns = {'index':'Country'}) # add column using old values of index

# %%
top
# Out:
#   Country   NOC
# 0     USA  1837
# 1     AUS   762
# 2     GER   691

# %%
sns.countplot(x = 'NOC', data = top, hue = y);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35636\585968642.py in <module>
# ----> 1 sns.countplot(x = 'NOC', data = top, hue = y);
#
# NameError: name 'y' is not defined
